# %%
# !pip install ./sacremoses/sacremoses-master/
# !pip install ./transformers/transformers-master/

STRIDE = 1
def is_jupyter():
    try:
        ipy_str = str(type(get_ipython()))
        if 'zmqshell' in ipy_str:
            return True
        
    except:
        return False

# %% [markdown]
# ### Required Imports
#
# I've added imports that will be used in training too

# %%
from sklearn.model_selection import train_test_split
import re
from random import shuffle as shfl
import random

from auc import MyAUCCallback
from sklearn.utils import shuffle
from datetime import datetime
import pandas as pd
pd.set_option('display.max.columns', 500)
import numpy as np
import os
# os.environ['CUDA_VISIBLE_DEVICES'] ='3'
# os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda-10.1/lib64'
import matplotlib.pyplot as plt
import gc
from shutil import copyfile
from catalyst.dl import SupervisedRunner, AlchemyLogger, CriterionCallback
from catalyst.dl.callbacks.metrics import AUCCallback
from torch.utils.data import DataLoader, SubsetRandomSampler,Dataset
batch_size =32
token = "d1dd16f08d518293bcbeddd313b49aa4"
DATA_DIR = '/kaggle/input/jigsaw-multilingual-toxic-comment-classification/'
# Out:
# /home/kb/jig_env/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
if os.uname()[1] == 'kb-Z370P-D3':
    # desktop
    LOG_PATH = '/media/ssd/logs/jigsaw'
    SERVER = False
    print('Working on desktop')
elif os.uname()[1] == 'kb-server':
    # server
    LOG_PATH = '/home/kb/logs/jigsaw'
    SERVER = True
    print('Working on server')
else:
    raise Exception('which hostname???')
# Out:
# Working on desktop

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')\
    .rename(columns={'content':'comment_text'})

# %%
df_pseudo = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/pseudo_labelling_09393.csv')
df_pseudo2 = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/pseudo_labelling_09459.csv')
df_pseudo = df_pseudo.merge(df_pseudo2, on='id')
df_pseudo = df_pseudo[((df_pseudo['toxic_x']>0.9) & (df_pseudo['toxic_y']>0.9)) | ((df_pseudo['toxic_x']<0.1) & (df_pseudo['toxic_y']<0.1))]
df_pseudo['toxic'] = (df_pseudo['toxic_y'] + df_pseudo['toxic_x'])/2
df_pseudo = df_pseudo[['id', 'toxic']]
df_pseudo.loc[df_pseudo['toxic']>0.5, 'toxic'] = 1.0
df_pseudo.loc[df_pseudo['toxic']<=0.5, 'toxic'] = 0.0
df_pseudo = df_pseudo.merge(df_test, on='id').rename(columns={'content':'comment_text'})

# %%
df_pseudo.head()
# Out:
#    id  toxic                                       comment_text lang
# 0   0    0.0  Doctor Who adlı viki başlığına 12. doctor olar...   tr
# 1   1    0.0   Вполне возможно, но я пока не вижу необходимо...   ru
# 2   3    0.0  Malesef gerçekleştirilmedi ancak şöyle bir şey...   tr
# 3   4    0.0  :Resim:Seldabagcan.jpg resminde kaynak sorunu ...   tr
# 4   5    0.0  Le truc le plus important dans ta tirade c est...   fr

# %%
len(df_pseudo)
# Out:
# 42421

# %%
df_pseudo.groupby('toxic', as_index=False)['id'].count()
# Out:
#    toxic     id
# 0    0.0  39129
# 1    1.0   3292

# %%
df_valid_3lng = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation.csv')
sub = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv')

# %%
target_column = 'toxic'

# %% [markdown]
# ### Define dataset

# %%
# 7from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split, cross_val_score, KFold
import time
from torch.optim import lr_scheduler

import torch
from tqdm import tqdm
#import torch.utils.data as data
from torchvision import datasets, models, transforms
from transformers import *
import random
from math import floor, ceil
from sklearn.model_selection import GroupKFold

MAX_LEN = 96#192#192#512
SEP_TOKEN_ID = 102

class QuestDataset(torch.utils.data.Dataset):
    def __init__(self, df, train_mode=True, labeled=True, train_transforms=None):
        
        self.train_transforms = train_transforms
        self.df = df
        if train_mode:
            self.labels = df.toxic.values
            self.toxic_inds = np.where(self.labels==1)[0]
            self.normal_inds = np.where(self.labels==0)[0]            
            
            
            print(f'Here is {len(self.labels)} samples, {len(self.toxic_inds)} samples and {len(self.normal_inds)} samples')
            print(f'Class balance is {len(self.toxic_inds)/len(self.labels):.2f}')
            
        self.train_mode = train_mode
        self.labeled = labeled

        self.tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-large')#, 


    def __getitem__(self, index):
        row = self.df.iloc[index]
        token_ids = self.get_token_ids(row)
        
        if self.labeled:
            labels = self.get_label(row)
            return {'features': token_ids, 'targets': labels}

        else:
            return {'features': token_ids}

    def __len__(self):
        return len(self.df)


        
    def get_token_ids(self, row):
        
        text = row.comment_text
        if self.train_transforms:
            lang = 'en' if 'lang' not in list(row.keys().values) else row.lang
            text, _ = self.train_transforms(data=(row.comment_text, lang))['data']
        
        if self.train_mode:
            token_ids = self.tokenizer.encode(text, max_length=1024)
            if len(token_ids) < MAX_LEN:
                ids = torch.tensor(token_ids + [0] * (MAX_LEN - len(token_ids)))
            else:
                ind_beg = random.randint(0, len(token_ids)-MAX_LEN)
                ids = torch.tensor(token_ids[ind_beg:ind_beg+MAX_LEN])
        else:
            token_ids = self.tokenizer.encode(text, max_length=MAX_LEN)
            if len(token_ids) < MAX_LEN:
                ids = torch.tensor(token_ids + [0] * (MAX_LEN - len(token_ids)))
            else:
                ids = torch.tensor(token_ids[:MAX_LEN])

        return ids

    def get_label(self, row):
        label = np.round(row[target_column])
        return torch.tensor([1-label, label]).float()
    
    def collate_fn(self, batch):
        token_ids = torch.stack([x[0] for x in batch])

        if self.labeled:
            labels = torch.stack([x[1] for x in batch])
            return {'features': token_ids, 'targets': labels}
        else:
            return {'features': token_ids}

# %% [markdown]
# ## Build Model

# %%
from transformers import *
import torch
import torch.nn as nn
import torch.nn.functional as F


class QuestModel(nn.Module):
    def __init__(self, n_classes=2):
        super(QuestModel, self).__init__()
        self.model_name = 'QuestModel'
    
        self.bert_model = XLMRobertaModel.from_pretrained('xlm-roberta-large')

        self.fc = nn.Linear(1024, n_classes)

    def forward(self, ids):

        layers = self.bert_model(input_ids=ids)
        out = F.dropout(layers[0][:, 0, :], p=0.2, training=self.training)
        logit = self.fc(out)
        return logit

# %%
# bert_model = XLMRobertaModel.from_pretrained('xlm-roberta-base')

# %%
class BalancedSampler(torch.utils.data.sampler.Sampler):
    def __init__(self, dataset):
       
        self.toxic_inds = dataset.toxic_inds.copy()
        self.normal_inds = dataset.normal_inds.copy()
        
        self.num_samples = 2*max(len(self.toxic_inds), len(self.normal_inds))
        
        random.Random(12345).shuffle(self.toxic_inds)
        random.Random(12345).shuffle(self.normal_inds)

        
        self.inds = []
        for i in range(max(len(self.toxic_inds), len(self.normal_inds))):
            self.inds.append(self.normal_inds[i%len(self.normal_inds)])
            self.inds.append(self.toxic_inds[i%len(self.toxic_inds)])

    def __iter__(self):
        #print ('\tcalling Sampler:__iter__')
        return iter(self.inds)

    def __len__(self):
        #print ('\tcalling Sampler:__len__')
        return self.num_samples

class BalancedSamplerRnd(torch.utils.data.sampler.Sampler):
    def __init__(self, dataset):
       
        self.toxic_inds = dataset.toxic_inds.copy()
        self.normal_inds = dataset.normal_inds.copy()
        
        self.num_samples = 2* len(self.normal_inds)
        
        random.Random(12345).shuffle(self.toxic_inds)
        random.Random(12345).shuffle(self.normal_inds)
        
        N = int(len(self.normal_inds) / len(self.toxic_inds))
        generated_seq = []
        for k in range(N):
            tmp = list(range(len(self.toxic_inds)))
            random.Random(12345).shuffle(tmp)
            generated_seq += tmp 
            
        generated_seq += tmp[:len(self.normal_inds)-len(generated_seq)]
        
        self.inds = []
        for i in range(len(self.normal_inds)):
            self.inds.append(self.normal_inds[i])
            self.inds.append(self.toxic_inds[generated_seq[i]])

    def __iter__(self):
        #print ('\tcalling Sampler:__iter__')
        return iter(self.inds)

    def __len__(self):
        #print ('\tcalling Sampler:__len__')
        return self.num_samples

# %%
def get_loaders(to_balance=True, shuffle_before=True):
    if SERVER:
        workers=1
    else:
        workers = 8    
    
    

    train_dataset = QuestDataset(df_pseudo, train_mode=True)#, train_transforms=get_train_transforms())
    valid_dataset = QuestDataset(df_valid_3lng, train_mode=False)
    
       
    train_loader = DataLoader(
        train_dataset,
        num_workers=workers,
        sampler=BalancedSamplerRnd(train_dataset) if to_balance else None,
        batch_size=batch_size,
    )
    valid_loader = DataLoader(
        valid_dataset,
        num_workers=workers,
        batch_size=batch_size,
    )    
    
       
    loaders = {}
    loaders['train'] = train_loader
    loaders['valid'] = valid_loader
    
    
    for i in ['es', 'it', 'tr']:
        df = df_valid_3lng
        df = df[df['lang']==i]

        loaders['valid_'+ i] = DataLoader(
            QuestDataset(df, train_mode=False),
            num_workers=workers,
            batch_size=batch_size,
        )
    
    
    return loaders

# %%
# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduce = reduce

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduce=False)
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduce=False)
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss

# %%
def freeze_until(net, param_name):
    found_name = False
    for name, params in net.named_parameters():
        if name == param_name:
            found_name = True
        params.requires_grad = found_name

def train_from_to(net, param_name_from, param_name_to):
    
    found_1_name = False
    found_2_name = False
    train_params = False
    
    for name, params in net.named_parameters():
        
        if not found_1_name:
            if name == param_name_from:
                train_params = True
                found_1_name = True
            
        elif not found_2_name:
            if name == param_name_to:
                train_params = False
                found_2_name = True
#         print(f'layer {name} will train? - {train_params}')
        params.requires_grad = train_params
        
# param_name = 'bert_model.encoder.layer.10.attention.self.query.weight'
param_name_from = 'bert_model.encoder.layer.8.attention.self.query.weight'
param_name_to = 'bert_model.encoder.layer.16.attention.self.query.weight'

CHECKPOINT = '/media/ssd/logs/jigsaw/js_v14_engbias/05082020_084031_lr1e-06_2stage_16lr/simple/checkpoints/best.pth'

project = "js_v14_engbias"
num_epochs = 300

group = datetime.now().strftime("%m%d%Y_%H%M%S")

    
if SERVER:
    group = f'{group}_srv'
    
if STRIDE > 1:
    group = f'{group}_str{STRIDE}'


gradient_accumulation_steps = 1

lr = 1e-7#1e-5#0.0001
group += f'_lr{lr}_3stage_16lr'

group = group.replace('.', '')

runner = SupervisedRunner(input_key=('features'), input_target_key=('targets'), output_key=('logits'))

experiment = 'simple'

torch.cuda.empty_cache()

logdir = f"{LOG_PATH}/{project}/{group}/{experiment}"

model = QuestModel(2)

checkpoint = torch.load(CHECKPOINT)#, map_location=device)   
model.load_state_dict(checkpoint['model_state_dict'])
del checkpoint

freeze_until(model, param_name_from)
# train_from_to(model, param_name_from, param_name_to)
# model = model.to(device)


loaders = get_loaders(to_balance=True)


t_total = len(loaders['train'])//gradient_accumulation_steps*num_epochs
warmup_proportion = 0.01
num_warmup_steps = t_total * warmup_proportion

#     criterion = torch.nn.BCEWithLogitsLoss()
criterion = FocalLoss(alpha=0.2, gamma=1.5, logits=True, reduce=True)
#     criterion = torch.nn.CrossEntropyLoss()
#     criterion = torch.nn.BCELoss()
optimizer = AdamW(model.parameters(), lr = lr)
#    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_warmup_steps, num_training_steps=t_total) 
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.25)
print(f'----------------Experiment: {experiment}')

runner.train(
    fp16=dict(opt_level="O1") ,
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    loaders=loaders,
    logdir=logdir,
    num_epochs=num_epochs,
    verbose=True,
    distributed=False if is_jupyter() else True,
    callbacks=[
        AlchemyLogger(
                token=token, # your Alchemy token
                project=project,
                experiment=experiment,
                group=group,
            ),
        MyAUCCallback()

    ],
    main_metric='auc/_mean',
    minimize_metric=False,
    
    #fp16={"opt_level": "O1"}

)
# Out:
# Here is 42421 samples, 3292 samples and 39129 samples
# Class balance is 0.08
# ----------------Experiment: simple
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Warning:  multi_tensor_applier fused unscale kernel is unavailable, possibly because apex was installed without --cuda_ext --cpp_ext. Using Python fallback.  Original ImportError was: ModuleNotFoundError("No module named 'amp_C'")
# 1/300 * Epoch (train):   0% 1/2446 [00:00<24:03,  1.69it/s, loss=0.002]
# /home/kb/jig_env/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning:
#
# size_average and reduce args will be deprecated, please use reduction='none' instead.
#
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning:
#
# This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# 1/300 * Epoch (train):  62% 1522/2446 [05:43<03:27,  4.46it/s, loss=0.001]    Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 1/300 * Epoch (train): 100% 2446/2446 [09:11<00:00,  4.43it/s, loss=1.060e-04]
# 1/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.81it/s, loss=0.003]
# 1/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.49it/s, loss=0.002]
# 1/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.35it/s, loss=0.001]
# 1/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.48it/s, loss=1.770e-04]
# [2020-05-09 10:01:47,877]
# 1/300 * Epoch 1 (_base): lr=1.000e-07 | momentum=0.9000
# 1/300 * Epoch 1 (train): auc/_mean=0.9992 | auc/class_0=0.9992 | loss=0.0029
# 1/300 * Epoch 1 (valid): auc/_mean=0.9397 | auc/class_0=0.9397 | es_auc/_mean=0.9231 | es_auc/class_0=0.9231 | es_loss=0.0309 | it_auc/_mean=0.9009 | it_auc/class_0=0.9009 | it_loss=0.0352 | loss=0.0249 | tr_auc/_mean=0.9847 | tr_auc/class_0=0.9847 | tr_loss=0.0106
# 1/300 * Epoch 1 (valid_es): auc/_mean=0.9231 | auc/class_0=0.9231 | loss=0.0309
# 1/300 * Epoch 1 (valid_it): auc/_mean=0.9009 | auc/class_0=0.9009 | loss=0.0352
# 1/300 * Epoch 1 (valid_tr): auc/_mean=0.9847 | auc/class_0=0.9847 | loss=0.0106
# 2/300 * Epoch (train):  87% 2135/2446 [08:01<01:09,  4.45it/s, loss=1.123e-04]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 2/300 * Epoch (train): 100% 2446/2446 [09:11<00:00,  4.43it/s, loss=3.153e-05]
# 2/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.74it/s, loss=0.003]
# 2/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.39it/s, loss=3.506e-04]
# 2/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.40it/s, loss=9.248e-04]
# 2/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.49it/s, loss=1.084e-04]
# [2020-05-09 10:12:37,644]
# 2/300 * Epoch 2 (_base): lr=1.000e-07 | momentum=0.9000
# 2/300 * Epoch 2 (train): auc/_mean=0.9995 | auc/class_0=0.9995 | loss=0.0020
# 2/300 * Epoch 2 (valid): auc/_mean=0.9399 | auc/class_0=0.9399 | es_auc/_mean=0.9213 | es_auc/class_0=0.9213 | es_loss=0.0336 | it_auc/_mean=0.9037 | it_auc/class_0=0.9037 | it_loss=0.0378 | loss=0.0270 | tr_auc/_mean=0.9825 | tr_auc/class_0=0.9825 | tr_loss=0.0119
# 2/300 * Epoch 2 (valid_es): auc/_mean=0.9213 | auc/class_0=0.9213 | loss=0.0336
# 2/300 * Epoch 2 (valid_it): auc/_mean=0.9037 | auc/class_0=0.9037 | loss=0.0378
# 2/300 * Epoch 2 (valid_tr): auc/_mean=0.9825 | auc/class_0=0.9825 | loss=0.0119
# 3/300 * Epoch (train): 100% 2446/2446 [09:09<00:00,  4.45it/s, loss=7.514e-05]
# 3/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.80it/s, loss=0.003]
# 3/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.45it/s, loss=4.164e-04]
# 3/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.35it/s, loss=7.095e-04]
# 3/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.46it/s, loss=9.415e-05]
# [2020-05-09 10:23:55,495]
# 3/300 * Epoch 3 (_base): lr=1.000e-07 | momentum=0.9000
# 3/300 * Epoch 3 (train): auc/_mean=0.9997 | auc/class_0=0.9997 | loss=0.0017
# 3/300 * Epoch 3 (valid): auc/_mean=0.9402 | auc/class_0=0.9402 | es_auc/_mean=0.9213 | es_auc/class_0=0.9213 | es_loss=0.0350 | it_auc/_mean=0.9054 | it_auc/class_0=0.9054 | it_loss=0.0392 | loss=0.0281 | tr_auc/_mean=0.9815 | tr_auc/class_0=0.9815 | tr_loss=0.0125
# 3/300 * Epoch 3 (valid_es): auc/_mean=0.9213 | auc/class_0=0.9213 | loss=0.0350
# 3/300 * Epoch 3 (valid_it): auc/_mean=0.9054 | auc/class_0=0.9054 | loss=0.0392
# 3/300 * Epoch 3 (valid_tr): auc/_mean=0.9815 | auc/class_0=0.9815 | loss=0.0125
# 4/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=2.658e-05]
# 4/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.77it/s, loss=0.003]
# 4/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.37it/s, loss=1.047e-04]
# 4/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.40it/s, loss=6.506e-04]
# 4/300 * Epoch (valid_tr): 100% 94/94 [00:07<00:00, 13.41it/s, loss=7.661e-05]
# [2020-05-09 10:35:14,991]
# 4/300 * Epoch 4 (_base): lr=1.000e-07 | momentum=0.9000
# 4/300 * Epoch 4 (train): auc/_mean=0.9997 | auc/class_0=0.9997 | loss=0.0015
# 4/300 * Epoch 4 (valid): auc/_mean=0.9394 | auc/class_0=0.9394 | es_auc/_mean=0.9196 | es_auc/class_0=0.9196 | es_loss=0.0366 | it_auc/_mean=0.9056 | it_auc/class_0=0.9056 | it_loss=0.0408 | loss=0.0295 | tr_auc/_mean=0.9802 | tr_auc/class_0=0.9802 | tr_loss=0.0133
# 4/300 * Epoch 4 (valid_es): auc/_mean=0.9196 | auc/class_0=0.9196 | loss=0.0366
# 4/300 * Epoch 4 (valid_it): auc/_mean=0.9056 | auc/class_0=0.9056 | loss=0.0408
# 4/300 * Epoch 4 (valid_tr): auc/_mean=0.9802 | auc/class_0=0.9802 | loss=0.0133
# 5/300 * Epoch (train):  44% 1068/2446 [04:00<05:08,  4.46it/s, loss=0.003]    Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 5/300 * Epoch (train):  61% 1495/2446 [05:36<03:34,  4.43it/s, loss=8.525e-05]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 5/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=5.215e-05]
# 5/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.81it/s, loss=0.003]
# 5/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.45it/s, loss=3.929e-04]
# 5/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.46it/s, loss=4.044e-04]
# 5/300 * Epoch (valid_tr): 100% 94/94 [00:07<00:00, 13.35it/s, loss=7.343e-05]
# [2020-05-09 10:45:45,205]
# 5/300 * Epoch 5 (_base): lr=1.000e-07 | momentum=0.9000
# 5/300 * Epoch 5 (train): auc/_mean=0.9998 | auc/class_0=0.9998 | loss=0.0013
# 5/300 * Epoch 5 (valid): auc/_mean=0.9396 | auc/class_0=0.9396 | es_auc/_mean=0.9197 | es_auc/class_0=0.9197 | es_loss=0.0382 | it_auc/_mean=0.9062 | it_auc/class_0=0.9062 | it_loss=0.0421 | loss=0.0305 | tr_auc/_mean=0.9799 | tr_auc/class_0=0.9799 | tr_loss=0.0136
# 5/300 * Epoch 5 (valid_es): auc/_mean=0.9197 | auc/class_0=0.9197 | loss=0.0382
# 5/300 * Epoch 5 (valid_it): auc/_mean=0.9062 | auc/class_0=0.9062 | loss=0.0421
# 5/300 * Epoch 5 (valid_tr): auc/_mean=0.9799 | auc/class_0=0.9799 | loss=0.0136
# 6/300 * Epoch (train):  49% 1202/2446 [04:30<04:39,  4.45it/s, loss=4.567e-04]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 6/300 * Epoch (train):  90% 2209/2446 [08:17<00:53,  4.44it/s, loss=6.565e-05]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 6/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=4.426e-05]
# 6/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.82it/s, loss=0.004]
# 6/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.50it/s, loss=0.002]
# 6/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.47it/s, loss=2.884e-04]
# 6/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.51it/s, loss=7.615e-05]
# [2020-05-09 10:56:12,717]
# 6/300 * Epoch 6 (_base): lr=1.000e-07 | momentum=0.9000
# 6/300 * Epoch 6 (train): auc/_mean=0.9998 | auc/class_0=0.9998 | loss=0.0012
# 6/300 * Epoch 6 (valid): auc/_mean=0.9394 | auc/class_0=0.9394 | es_auc/_mean=0.9195 | es_auc/class_0=0.9195 | es_loss=0.0402 | it_auc/_mean=0.9064 | it_auc/class_0=0.9064 | it_loss=0.0439 | loss=0.0319 | tr_auc/_mean=0.9796 | tr_auc/class_0=0.9796 | tr_loss=0.0141
# 6/300 * Epoch 6 (valid_es): auc/_mean=0.9195 | auc/class_0=0.9195 | loss=0.0402
# 6/300 * Epoch 6 (valid_it): auc/_mean=0.9064 | auc/class_0=0.9064 | loss=0.0439
# 6/300 * Epoch 6 (valid_tr): auc/_mean=0.9796 | auc/class_0=0.9796 | loss=0.0141
# 7/300 * Epoch (train): 100% 2446/2446 [09:11<00:00,  4.44it/s, loss=1.248e-04]
# 7/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.70it/s, loss=0.004]
# 7/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.42it/s, loss=9.679e-04]
# 7/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.32it/s, loss=2.755e-04]
# 7/300 * Epoch (valid_tr): 100% 94/94 [00:07<00:00, 13.37it/s, loss=6.794e-05]
# [2020-05-09 11:06:40,667]
# 7/300 * Epoch 7 (_base): lr=1.000e-07 | momentum=0.9000
# 7/300 * Epoch 7 (train): auc/_mean=0.9998 | auc/class_0=0.9998 | loss=0.0011
# 7/300 * Epoch 7 (valid): auc/_mean=0.9390 | auc/class_0=0.9390 | es_auc/_mean=0.9188 | es_auc/class_0=0.9188 | es_loss=0.0406 | it_auc/_mean=0.9066 | it_auc/class_0=0.9066 | it_loss=0.0446 | loss=0.0325 | tr_auc/_mean=0.9788 | tr_auc/class_0=0.9788 | tr_loss=0.0148
# 7/300 * Epoch 7 (valid_es): auc/_mean=0.9188 | auc/class_0=0.9188 | loss=0.0406
# 7/300 * Epoch 7 (valid_it): auc/_mean=0.9066 | auc/class_0=0.9066 | loss=0.0446
# 7/300 * Epoch 7 (valid_tr): auc/_mean=0.9788 | auc/class_0=0.9788 | loss=0.0148
# 8/300 * Epoch (train):  40% 976/2446 [03:39<05:31,  4.44it/s, loss=5.942e-04]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 8/300 * Epoch (train): 100% 2446/2446 [09:09<00:00,  4.45it/s, loss=2.269e-05]
# 8/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.79it/s, loss=0.005]
# 8/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.38it/s, loss=0.003]
# 8/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.42it/s, loss=1.265e-04]
# 8/300 * Epoch (valid_tr): 100% 94/94 [00:07<00:00, 13.39it/s, loss=8.134e-05]
# [2020-05-09 11:17:05,898]
# 8/300 * Epoch 8 (_base): lr=1.000e-07 | momentum=0.9000
# 8/300 * Epoch 8 (train): auc/_mean=0.9999 | auc/class_0=0.9999 | loss=0.0010
# 8/300 * Epoch 8 (valid): auc/_mean=0.9397 | auc/class_0=0.9397 | es_auc/_mean=0.9192 | es_auc/class_0=0.9192 | es_loss=0.0437 | it_auc/_mean=0.9078 | it_auc/class_0=0.9078 | it_loss=0.0466 | loss=0.0341 | tr_auc/_mean=0.9795 | tr_auc/class_0=0.9795 | tr_loss=0.0149
# 8/300 * Epoch 8 (valid_es): auc/_mean=0.9192 | auc/class_0=0.9192 | loss=0.0437
# 8/300 * Epoch 8 (valid_it): auc/_mean=0.9078 | auc/class_0=0.9078 | loss=0.0466
# 8/300 * Epoch 8 (valid_tr): auc/_mean=0.9795 | auc/class_0=0.9795 | loss=0.0149
# 9/300 * Epoch (train):  82% 1995/2446 [07:29<01:41,  4.45it/s, loss=1.655e-04]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 9/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=8.737e-06]
# 9/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.81it/s, loss=0.004]
# 9/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.50it/s, loss=0.003]
# 9/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.50it/s, loss=9.736e-05]
# 9/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.49it/s, loss=7.027e-05]
# [2020-05-09 11:27:34,405]
# 9/300 * Epoch 9 (_base): lr=1.000e-07 | momentum=0.9000
# 9/300 * Epoch 9 (train): auc/_mean=0.9999 | auc/class_0=0.9999 | loss=0.0009
# 9/300 * Epoch 9 (valid): auc/_mean=0.9393 | auc/class_0=0.9393 | es_auc/_mean=0.9190 | es_auc/class_0=0.9190 | es_loss=0.0454 | it_auc/_mean=0.9080 | it_auc/class_0=0.9080 | it_loss=0.0485 | loss=0.0355 | tr_auc/_mean=0.9789 | tr_auc/class_0=0.9789 | tr_loss=0.0156
# 9/300 * Epoch 9 (valid_es): auc/_mean=0.9190 | auc/class_0=0.9190 | loss=0.0454
# 9/300 * Epoch 9 (valid_it): auc/_mean=0.9080 | auc/class_0=0.9080 | loss=0.0485
# 9/300 * Epoch 9 (valid_tr): auc/_mean=0.9789 | auc/class_0=0.9789 | loss=0.0156
# 10/300 * Epoch (train):  28% 696/2446 [02:36<06:32,  4.46it/s, loss=2.325e-04]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 10/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=7.352e-06]
# 10/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.82it/s, loss=0.005]
# 10/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.44it/s, loss=6.234e-04]
# 10/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.51it/s, loss=8.025e-05]
# 10/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.49it/s, loss=5.498e-05]
# [2020-05-09 11:38:01,822]
# 10/300 * Epoch 10 (_base): lr=1.000e-07 | momentum=0.9000
# 10/300 * Epoch 10 (train): auc/_mean=0.9999 | auc/class_0=0.9999 | loss=0.0008
# 10/300 * Epoch 10 (valid): auc/_mean=0.9391 | auc/class_0=0.9391 | es_auc/_mean=0.9188 | es_auc/class_0=0.9188 | es_loss=0.0456 | it_auc/_mean=0.9076 | it_auc/class_0=0.9076 | it_loss=0.0495 | loss=0.0361 | tr_auc/_mean=0.9787 | tr_auc/class_0=0.9787 | tr_loss=0.0162
# 10/300 * Epoch 10 (valid_es): auc/_mean=0.9188 | auc/class_0=0.9188 | loss=0.0456
# 10/300 * Epoch 10 (valid_it): auc/_mean=0.9076 | auc/class_0=0.9076 | loss=0.0495
# 10/300 * Epoch 10 (valid_tr): auc/_mean=0.9787 | auc/class_0=0.9787 | loss=0.0162
# 11/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=4.568e-06]
# 11/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.82it/s, loss=0.004]
# 11/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.45it/s, loss=1.536e-04]
# 11/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.48it/s, loss=7.204e-05]
# 11/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.51it/s, loss=4.233e-05]
# [2020-05-09 11:48:27,490]
# 11/300 * Epoch 11 (_base): lr=1.000e-07 | momentum=0.9000
# 11/300 * Epoch 11 (train): auc/_mean=0.9999 | auc/class_0=0.9999 | loss=0.0008
# 11/300 * Epoch 11 (valid): auc/_mean=0.9390 | auc/class_0=0.9390 | es_auc/_mean=0.9179 | es_auc/class_0=0.9179 | es_loss=0.0465 | it_auc/_mean=0.9079 | it_auc/class_0=0.9079 | it_loss=0.0503 | loss=0.0369 | tr_auc/_mean=0.9785 | tr_auc/class_0=0.9785 | tr_loss=0.0167
# 11/300 * Epoch 11 (valid_es): auc/_mean=0.9179 | auc/class_0=0.9179 | loss=0.0465
# 11/300 * Epoch 11 (valid_it): auc/_mean=0.9079 | auc/class_0=0.9079 | loss=0.0503
# 11/300 * Epoch 11 (valid_tr): auc/_mean=0.9785 | auc/class_0=0.9785 | loss=0.0167
# 12/300 * Epoch (train):   7% 164/2446 [00:37<08:32,  4.46it/s, loss=3.375e-05]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 12/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=5.571e-06]
# 12/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.80it/s, loss=0.006]
# 12/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.48it/s, loss=0.001]
# 12/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.50it/s, loss=4.616e-05]
# 12/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.47it/s, loss=5.670e-05]
# [2020-05-09 11:58:54,863]
# 12/300 * Epoch 12 (_base): lr=1.000e-07 | momentum=0.9000
# 12/300 * Epoch 12 (train): auc/_mean=0.9999 | auc/class_0=0.9999 | loss=0.0007
# 12/300 * Epoch 12 (valid): auc/_mean=0.9391 | auc/class_0=0.9391 | es_auc/_mean=0.9183 | es_auc/class_0=0.9183 | es_loss=0.0479 | it_auc/_mean=0.9078 | it_auc/class_0=0.9078 | it_loss=0.0515 | loss=0.0378 | tr_auc/_mean=0.9788 | tr_auc/class_0=0.9788 | tr_loss=0.0169
# 12/300 * Epoch 12 (valid_es): auc/_mean=0.9183 | auc/class_0=0.9183 | loss=0.0479
# 12/300 * Epoch 12 (valid_it): auc/_mean=0.9078 | auc/class_0=0.9078 | loss=0.0515
# 12/300 * Epoch 12 (valid_tr): auc/_mean=0.9788 | auc/class_0=0.9788 | loss=0.0169
# 13/300 * Epoch (train):   3% 84/2446 [00:19<08:49,  4.46it/s, loss=1.132e-05]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 13/300 * Epoch (train): 100% 2446/2446 [09:09<00:00,  4.45it/s, loss=4.093e-06]
# 13/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.80it/s, loss=0.005]
# 13/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.49it/s, loss=0.002]
# 13/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.46it/s, loss=6.056e-05]
# 13/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.46it/s, loss=3.616e-05]
# [2020-05-09 12:09:20,423]
# 13/300 * Epoch 13 (_base): lr=1.000e-07 | momentum=0.9000
# 13/300 * Epoch 13 (train): auc/_mean=0.9999 | auc/class_0=0.9999 | loss=0.0006
# 13/300 * Epoch 13 (valid): auc/_mean=0.9373 | auc/class_0=0.9373 | es_auc/_mean=0.9164 | es_auc/class_0=0.9164 | es_loss=0.0486 | it_auc/_mean=0.9056 | it_auc/class_0=0.9056 | it_loss=0.0543 | loss=0.0395 | tr_auc/_mean=0.9775 | tr_auc/class_0=0.9775 | tr_loss=0.0186
# 13/300 * Epoch 13 (valid_es): auc/_mean=0.9164 | auc/class_0=0.9164 | loss=0.0486
# 13/300 * Epoch 13 (valid_it): auc/_mean=0.9056 | auc/class_0=0.9056 | loss=0.0543
# 13/300 * Epoch 13 (valid_tr): auc/_mean=0.9775 | auc/class_0=0.9775 | loss=0.0186
# 14/300 * Epoch (train):   5% 117/2446 [00:26<08:41,  4.47it/s, loss=8.471e-04]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 14/300 * Epoch (train): 100% 2446/2446 [09:10<00:00,  4.44it/s, loss=6.381e-06]
# 14/300 * Epoch (valid): 100% 250/250 [00:18<00:00, 13.80it/s, loss=0.006]
# 14/300 * Epoch (valid_es): 100% 79/79 [00:05<00:00, 13.47it/s, loss=0.002]
# 14/300 * Epoch (valid_it): 100% 79/79 [00:05<00:00, 13.44it/s, loss=2.124e-05]
# 14/300 * Epoch (valid_tr): 100% 94/94 [00:06<00:00, 13.44it/s, loss=3.666e-05]
# [2020-05-09 12:19:47,501]
# 14/300 * Epoch 14 (_base): lr=1.000e-07 | momentum=0.9000
# 14/300 * Epoch 14 (train): auc/_mean=1.0000 | auc/class_0=1.0000 | loss=0.0006
# 14/300 * Epoch 14 (valid): auc/_mean=0.9377 | auc/class_0=0.9377 | es_auc/_mean=0.9172 | es_auc/class_0=0.9172 | es_loss=0.0515 | it_auc/_mean=0.9064 | it_auc/class_0=0.9064 | it_loss=0.0557 | loss=0.0409 | tr_auc/_mean=0.9772 | tr_auc/class_0=0.9772 | tr_loss=0.0187
# 14/300 * Epoch 14 (valid_es): auc/_mean=0.9172 | auc/class_0=0.9172 | loss=0.0515
# 14/300 * Epoch 14 (valid_it): auc/_mean=0.9064 | auc/class_0=0.9064 | loss=0.0557
# 14/300 * Epoch 14 (valid_tr): auc/_mean=0.9772 | auc/class_0=0.9772 | loss=0.0187
# 15/300 * Epoch (train):   3% 84/2446 [00:19<08:47,  4.47it/s, loss=7.020e-06]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 15/300 * Epoch (train):  24% 588/2446 [02:12<06:58,  4.44it/s, loss=5.182e-05]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# Early exiting
# 15/300 * Epoch (train):  75% 1832/2446 [06:52<02:19,  4.42it/s, loss=7.476e-04]

# %%
# for i, row in df_train.iterrows():
#     print(list(row.keys().values))
#     break

# %%
--
# Out:
#   File "<ipython-input-20-4071a1fba099>", line 1
#     --
#       ^
# SyntaxError: invalid syntax

# %%
CHECKPOINT = '/media/ssd/logs/jigsaw/js_v14_engbias/05092020_095135_lr1e-07_3stage_16lr/simple/checkpoints/best.pth'

# %%
# model = QuestModel(2)

checkpoint = torch.load(CHECKPOINT)#, map_location=device)   

model.load_state_dict(checkpoint['model_state_dict'])
del checkpoint

# %%
# model = model.to(device)
_ = model.eval()

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')\
    .rename(columns={'content':'comment_text'})
ds = QuestDataset(df_test, train_mode=False, labeled=False)
loader = DataLoader(
        ds,
        num_workers=8,
        batch_size=batch_size,
    )

# %%
df_test.head()
# Out:
#    id                                       comment_text lang
# 0   0  Doctor Who adlı viki başlığına 12. doctor olar...   tr
# 1   1   Вполне возможно, но я пока не вижу необходимо...   ru
# 2   2  Quindi tu sei uno di quelli   conservativi  , ...   it
# 3   3  Malesef gerçekleştirilmedi ancak şöyle bir şey...   tr
# 4   4  :Resim:Seldabagcan.jpg resminde kaynak sorunu ...   tr

# %%
y_pred = torch.zeros( len(ds), 2).to(device)

j = 0
with torch.no_grad():
    for data in tqdm(loader):
        x = data['features'].to(device)
        thish_batch_size = len(x)            
        
        
        y_pred[j:j+thish_batch_size] = model(x)
            
        j += thish_batch_size
# Out:
#   0%|          | 0/1995 [00:00<?, ?it/s]
#   0%|          | 1/1995 [00:00<08:12,  4.05it/s]
#   0%|          | 3/1995 [00:00<06:33,  5.06it/s]
#   0%|          | 5/1995 [00:00<05:23,  6.16it/s]
#   0%|          | 7/1995 [00:00<04:26,  7.46it/s]
#   0%|          | 9/1995 [00:00<03:46,  8.76it/s]
#   1%|          | 11/1995 [00:00<03:18,  9.98it/s]
#   1%|          | 13/1995 [00:01<02:59, 11.04it/s]
#   1%|          | 15/1995 [00:01<02:46, 11.90it/s]
#   1%|          | 17/1995 [00:01<02:36, 12.62it/s]
#   1%|          | 19/1995 [00:01<02:29, 13.22it/s]
#   1%|          | 21/1995 [00:01<02:25, 13.61it/s]
#   1%|          | 23/1995 [00:01<02:21, 13.92it/s]
#   1%|▏         | 25/1995 [00:01<02:23, 13.76it/s]
#   1%|▏         | 27/1995 [00:02<02:21, 13.93it/s]
#   1%|▏         | 29/1995 [00:02<02:15, 14.49it/s]
#   2%|▏         | 31/1995 [00:02<02:16, 14.35it/s]
#   2%|▏         | 33/1995 [00:02<02:16, 14.39it/s]
#   2%|▏         | 35/1995 [00:02<02:13, 14.70it/s]
#   2%|▏         | 37/1995 [00:02<02:12, 14.76it/s]
#   2%|▏         | 39/1995 [00:02<02:12, 14.73it/s]
#   2%|▏         | 41/1995 [00:03<02:12, 14.70it/s]
#   2%|▏         | 43/1995 [00:03<02:12, 14.71it/s]
#  96%|█████████▋| 1923/1995 [02:12<00:04, 14.49it/s]
#  96%|█████████▋| 1925/1995 [02:13<00:04, 14.51it/s]
#  97%|█████████▋| 1927/1995 [02:13<00:04, 14.48it/s]
#  97%|█████████▋| 1929/1995 [02:13<00:04, 14.43it/s]
#  97%|█████████▋| 1931/1995 [02:13<00:04, 14.45it/s]
#  97%|█████████▋| 1933/1995 [02:13<00:04, 14.46it/s]
#  97%|█████████▋| 1935/1995 [02:13<00:04, 14.42it/s]
#  97%|█████████▋| 1937/1995 [02:13<00:04, 14.47it/s]
#  97%|█████████▋| 1939/1995 [02:14<00:03, 14.36it/s]
#  97%|█████████▋| 1941/1995 [02:14<00:03, 14.33it/s]
#  97%|█████████▋| 1943/1995 [02:14<00:03, 14.45it/s]
#  97%|█████████▋| 1945/1995 [02:14<00:03, 14.46it/s]
#  98%|█████████▊| 1947/1995 [02:14<00:03, 14.45it/s]
#  98%|█████████▊| 1949/1995 [02:14<00:03, 14.53it/s]
#  98%|█████████▊| 1951/1995 [02:14<00:03, 14.50it/s]
#  98%|█████████▊| 1953/1995 [02:15<00:02, 14.48it/s]
#  98%|█████████▊| 1955/1995 [02:15<00:02, 14.45it/s]
#  98%|█████████▊| 1957/1995 [02:15<00:02, 14.47it/s]
#  98%|█████████▊| 1959/1995 [02:15<00:02, 14.47it/s]
#  98%|█████████▊| 1961/1995 [02:15<00:02, 14.46it/s]
#  98%|█████████▊| 1963/1995 [02:15<00:02, 14.45it/s]
#  98%|█████████▊| 1965/1995 [02:15<00:02, 14.47it/s]
#  99%|█████████▊| 1967/1995 [02:15<00:01, 14.06it/s]
#  99%|█████████▊| 1969/1995 [02:16<00:01, 14.52it/s]
#  99%|█████████▉| 1971/1995 [02:16<00:01, 14.49it/s]
#  99%|█████████▉| 1973/1995 [02:16<00:01, 14.55it/s]
#  99%|█████████▉| 1975/1995 [02:16<00:01, 14.45it/s]
#  99%|█████████▉| 1977/1995 [02:16<00:01, 14.53it/s]
#  99%|█████████▉| 1979/1995 [02:16<00:01, 14.50it/s]
#  99%|█████████▉| 1981/1995 [02:16<00:00, 14.37it/s]
#  99%|█████████▉| 1983/1995 [02:17<00:00, 14.48it/s]
#  99%|█████████▉| 1985/1995 [02:17<00:00, 14.49it/s]
# 100%|█████████▉| 1987/1995 [02:17<00:00, 14.46it/s]
# 100%|█████████▉| 1989/1995 [02:17<00:00, 14.52it/s]
# 100%|█████████▉| 1991/1995 [02:17<00:00, 14.51it/s]
# 100%|█████████▉| 1993/1995 [02:17<00:00, 14.47it/s]
# 100%|██████████| 1995/1995 [02:17<00:00, 14.46it/s]

# %%
from torch import sigmoid
y_pred_sigmoid = sigmoid(y_pred)

# %%
y_pred_sigmoid_one_np = y_pred_sigmoid.cpu().numpy()

# %%
df_sub = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv')

# %%
df_sub['toxic'] = y_pred_sigmoid_one_np[:,1]

# %%
df_sub.to_csv('submission_v1421.csv', index=False)

# %%
df_sub
