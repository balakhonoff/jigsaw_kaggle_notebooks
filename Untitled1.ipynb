# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')

# %%
# df_sub = pd.read_csv('/media/ssd/Downloads/submission (4).csv')
df_sub_my = pd.read_csv('/media/ssd/Downloads/submission (5).csv')
df_sub_sh = pd.read_csv('/media/ssd/Downloads/submission (6).csv')

# %%
# Out:
#    id                                            content lang     toxic
# 0   0  Doctor Who adlı viki başlığına 12. doctor olar...   tr  0.046206
# 1   1   Вполне возможно, но я пока не вижу необходимо...   ru  0.163445
# 2   2  Quindi tu sei uno di quelli   conservativi  , ...   it  0.587529
# 3   3  Malesef gerçekleştirilmedi ancak şöyle bir şey...   tr  0.025761
# 4   4  :Resim:Seldabagcan.jpg resminde kaynak sorunu ...   tr  0.030792

# %%
len(df_test), len(df_sub)
# Out:
# (63812, 63812)

# %%
df_test.head()
# Out:
#    id                                            content lang
# 0   0  Doctor Who adlı viki başlığına 12. doctor olar...   tr
# 1   1   Вполне возможно, но я пока не вижу необходимо...   ru
# 2   2  Quindi tu sei uno di quelli   conservativi  , ...   it
# 3   3  Malesef gerçekleştirilmedi ancak şöyle bir şey...   tr
# 4   4  :Resim:Seldabagcan.jpg resminde kaynak sorunu ...   tr

# %%
df_sub.head()
# Out:
#    id     toxic
# 0   0  0.001314
# 1   1  0.000215
# 2   2  0.256351
# 3   3  0.000270
# 4   4  0.000254

# %%
df_sub_my= df_test.merge(df_sub_my, on ='id')
len(df_test)
# Out:
# 63812

# %%
df_sub_sh= df_test.merge(df_sub_sh, on ='id')
len(df_test)
# Out:
# 63812

# %%
plt.figure()
plt.hist(np.power(df_sub_sh.toxic,1/4.2), bins=100, color='r')
plt.hist(np.power(df_sub_my.toxic,1/2), bins=100, color='g')
plt.show()

plt.figure()
plt.hist(np.power(df_sub_my.toxic,1/2), bins=100, color='g')
plt.hist(np.power(df_sub_sh.toxic,1/4.2), bins=100, color='r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
df_sub = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv')
df_sub.head()
# Out:
#    id  toxic
# 0   0    0.5
# 1   1    0.5
# 2   2    0.5
# 3   3    0.5
# 4   4    0.5

# %%
df_sub['toxic'] = (np.power(df_sub_sh.toxic,1/4.2)+np.power(df_sub_my.toxic,1/2))/2
df_sub.to_csv('09340_09358_scaled_v1.csv', index=False)

# %%
plt.figure()
plt.hist((np.power(df_sub_sh.toxic,1/4.2)+np.power(df_sub_my.toxic,1/2))/2, bins=100, color='g')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
colors = ['r', 'g', 'b', 'k', 'c', 'm']
plt.figure()
legend = []
for i, lang in enumerate(['tr', 'pt', 'ru', 'fr', 'it',  'es']):
    plt.hist(df_sub_my[df_sub_my['lang']==lang].toxic, bins=100, color=colors[i])
    legend.append(lang)
    
plt.legend(legend)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook

def collapse(x):
#     return x
    p = 1
    
#     a =  2*(x - 0.5)  # -1..1
    
#     sgn = np.sign(a)
#     abs_a = np.abs(a)
  
#     b = sgn * np.power(abs_a, p)
    
#     c = b/2 + 0.5
    
    return np.power(x, p)


colors = ['r', 'g', 'b', 'k', 'c', 'm']
plt.figure()
legend = []
for i, lang in enumerate(['tr', 'pt', 'ru', 'fr', 'it',  'es']):
    plt.hist(collapse(df_sub_my[df_sub_my['lang']==lang].toxic), bins=100, color=colors[i])
    legend.append(lang)
    
plt.legend(legend)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook

def collapse(x):
#     return x
    p = 1/3
    
#     a =  2*(x - 0.5)  # -1..1
    
#     sgn = np.sign(a)
#     abs_a = np.abs(a)
  
#     b = sgn * np.power(abs_a, p)
    
#     c = b/2 + 0.5
    
    return np.power(x, p)


colors = ['r', 'g', 'b', 'k', 'c', 'm']
plt.figure()
legend = []
for i, lang in enumerate(['tr', 'pt', 'ru', 'fr', 'it',  'es']):
    plt.hist(collapse(df_sub_sh[df_sub_sh['lang']==lang].toxic), bins=100, color=colors[i])
    
    legend.append(lang)
    
plt.legend(legend)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
# %matplotlib notebook
colors = ['r', 'g', 'b', 'k', 'c', 'm']
plt.figure()
legend = []
for i, lang in enumerate(['tr', 'pt', 'ru', 'fr', 'it',  'es']):
    plt.hist(df_test[df_test['lang']==lang].toxic, bins=100, color=colors[i])
    legend.append(lang)
    
plt.legend(legend)
plt.show()

# %%
# %matplotlib notebook
plt.figure()
legend = []
for i, lang in enumerate(['tr', 'pt', 'ru', 'fr', 'it',  'es'][-1::-1]):
    plt.hist(df_test[df_test['lang']==lang].toxic, bins=1000, color=colors[-1::-1][i])
    legend.append(lang)
    
plt.legend(legend)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">

# %%
plt.figure()
plt.hist(df_test[df_test['lang']=='pt'].toxic, bins=100, color=colors[-1::-1][i])
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
# (array([5755.,  271.,  195.,  162.,  146.,  147.,  119.,  146.,  144.,
#          136.,  124.,  109.,  134.,  111.,  121.,  136.,  106.,  117.,
#          118.,   85.,  101.,   95.,   99.,   98.,   80.,   87.,   84.,
#           77.,   70.,   56.,   55.,   72.,   65.,   49.,   55.,   50.,
#           42.,   36.,   36.,   42.,   42.,   28.,   32.,   19.,   28.,
#           29.,   28.,   23.,   13.,   17.,   20.,   20.,   12.,   14.,
#           20.,   17.,   13.,   19.,   13.,   15.,   11.,   13.,   14.,
#           13.,   16.,   13.,   14.,   16.,   11.,   10.,   13.,    9.,
#           10.,   16.,   12.,   13.,   10.,   10.,   10.,    8.,   11.,
#           16.,   18.,   11.,   10.,   12.,   19.,   11.,   16.,   16.,
#           10.,   21.,   17.,   12.,   25.,   24.,   40.,   48.,   56.,
#          224.]),
#  array([7.95424000e-05, 1.00745780e-02, 2.00696136e-02, 3.00646491e-02,
# ...

# %%
df_test.lang.unique()
# Out:
# array(['tr', 'ru', 'it', 'fr', 'pt', 'es'], dtype=object)

# %%
df_test.groupby('lang', as_index=False)['id'].count().sort_values('id')
# Out:
#   lang     id
# 0   es   8438
# 2   it   8494
# 1   fr  10920
# 4   ru  10948
# 3   pt  11012
# 5   tr  14000

# %%
# %matplotlib notebook
colors = ['r', 'g', 'b', 'k', 'c', 'm']
plt.figure()
legend = []
for i, lang in enumerate(['tr', 'pt', 'ru', 'fr', 'it',  'es']):
    plt.hist(df_test[df_test['lang']==lang].toxic, bins=100, color=colors[i])
    legend.append(lang)
    
plt.legend(legend)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="638.888905813665">
