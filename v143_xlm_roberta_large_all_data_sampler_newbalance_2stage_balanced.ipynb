# %%
# !pip install ./sacremoses/sacremoses-master/
# !pip install ./transformers/transformers-master/

STRIDE = 1
def is_jupyter():
    try:
        ipy_str = str(type(get_ipython()))
        if 'zmqshell' in ipy_str:
            return True
        
    except:
        return False

# %% [markdown]
# ### Required Imports
#
# I've added imports that will be used in training too

# %%
from sklearn.model_selection import train_test_split
import re
from random import shuffle as shfl
from auc import MyAUCCallback
from sklearn.utils import shuffle
from datetime import datetime
import pandas as pd
pd.set_option('display.max.columns', 500)
import numpy as np
import os
# os.environ['CUDA_VISIBLE_DEVICES'] ='3'
# os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda-10.1/lib64'
import matplotlib.pyplot as plt
import gc
from shutil import copyfile
from catalyst.dl import SupervisedRunner, AlchemyLogger, CriterionCallback
from catalyst.dl.callbacks.metrics import AUCCallback
from torch.utils.data import DataLoader, SubsetRandomSampler,Dataset
batch_size =64
token = "d1dd16f08d518293bcbeddd313b49aa4"
DATA_DIR = '/kaggle/input/jigsaw-multilingual-toxic-comment-classification/'
# Out:
# /home/kb/jig_env/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
if os.uname()[1] == 'kb-Z370P-D3':
    # desktop
    LOG_PATH = '/media/ssd/logs/jigsaw'
    SERVER = False
    print('Working on desktop')
elif os.uname()[1] == 'kb-server':
    # server
    LOG_PATH = '/home/kb/logs/jigsaw'
    SERVER = True
    print('Working on server')
else:
    raise Exception('which hostname???')
# Out:
# Working on desktop

# %%
df_train = None
df_valid = None
for lang in ['es', 'tr', 'it', 'ru', 'pt', 'fr']:
    df_temp = pd.read_csv(f'/kaggle/input/jigsaw-multilingual-toxic-comment-classification/google/jigsaw-toxic-comment-train-google-{lang}-cleaned.csv')
    
    df_temp = pd.concat([
        df_temp[['comment_text', 'toxic']].query('toxic==1'),
        df_temp[['comment_text', 'toxic']].query('toxic==0').sample(n=21378, random_state=0)
    ])

    df_train_lng, df_valid_lng = train_test_split(df_temp, random_state=12345, 
                                         stratify=df_temp.toxic.values, test_size=0.1)
    
    if df_train is None:
        df_train = df_train_lng.copy()
        df_valid = df_valid_lng.copy()
        
    else:
        df_train = df_train.append(df_train_lng[df_train.columns]).reset_index(drop=True)
        df_valid = df_valid.append(df_valid_lng[df_train.columns]).reset_index(drop=True)
        
    print(len(df_train))
    
df_temp = pd.read_csv(f'/kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-toxic-comment-train.csv')
df_temp = pd.concat([
        df_temp[['comment_text', 'toxic']].query('toxic==1'),
        df_temp[['comment_text', 'toxic']].query('toxic==0')#.sample(n=21378, random_state=0)
    ])
df_train_lng, df_valid_lng = train_test_split(df_temp, random_state=12345, 
                                         stratify=df_temp.toxic.values, test_size=0.1)
df_train = df_train.append(df_train_lng[df_train.columns]).reset_index(drop=True)
df_valid = df_valid.append(df_valid_lng[df_train.columns]).reset_index(drop=True)
print(len(df_train))
# Out:
# 38476
# 76956
# 115436
# 153902
# 192382
# 230862
# 432056

# %%
df_valid_3lng = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation.csv')
sub = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv')

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')\
    .rename(columns={'content':'comment_text'})

# %%
target_column = 'toxic'

# %% [markdown]
# ### Define dataset

# %%
# 7from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split, cross_val_score, KFold
import time
from torch.optim import lr_scheduler

import torch
from tqdm import tqdm
#import torch.utils.data as data
from torchvision import datasets, models, transforms
from transformers import *
import random
from math import floor, ceil
from sklearn.model_selection import GroupKFold

MAX_LEN = 96#192#192#512
SEP_TOKEN_ID = 102

class QuestDataset(torch.utils.data.Dataset):
    def __init__(self, df, train_mode=True, labeled=True, train_transforms=None):
        
        self.train_transforms = train_transforms
        self.df = df
        if train_mode:
            self.labels = df.toxic.values
            self.toxic_inds = np.where(self.labels==1)[0]
            self.normal_inds = np.where(self.labels==0)[0]            
            
            
            print(f'Here is {len(self.labels)} samples, {len(self.toxic_inds)} samples and {len(self.normal_inds)} samples')
            print(f'Class balance is {len(self.toxic_inds)/len(self.labels):.2f}')
            
        self.train_mode = train_mode
        self.labeled = labeled

        self.tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-large')#, 


    def __getitem__(self, index):
        row = self.df.iloc[index]
        token_ids = self.get_token_ids(row)
        
        if self.labeled:
            labels = self.get_label(row)
            return {'features': token_ids, 'targets': labels}

        else:
            return {'features': token_ids}

    def __len__(self):
        return len(self.df)


        
    def get_token_ids(self, row):
        
        text = row.comment_text
        if self.train_transforms:
            lang = 'en' if 'lang' not in list(row.keys().values) else row.lang
            text, _ = self.train_transforms(data=(row.comment_text, lang))['data']
        
        if self.train_mode:
            token_ids = self.tokenizer.encode(text, max_length=1024)
            if len(token_ids) < MAX_LEN:
                ids = torch.tensor(token_ids + [0] * (MAX_LEN - len(token_ids)))
            else:
                ind_beg = random.randint(0, len(token_ids)-MAX_LEN)
                ids = torch.tensor(token_ids[ind_beg:ind_beg+MAX_LEN])
        else:
            token_ids = self.tokenizer.encode(text, max_length=MAX_LEN)
            if len(token_ids) < MAX_LEN:
                ids = torch.tensor(token_ids + [0] * (MAX_LEN - len(token_ids)))
            else:
                ids = torch.tensor(token_ids[:MAX_LEN])

        return ids

    def get_label(self, row):
        label = np.round(row[target_column])
        return torch.tensor([1-label, label]).float()
    
    def collate_fn(self, batch):
        token_ids = torch.stack([x[0] for x in batch])

        if self.labeled:
            labels = torch.stack([x[1] for x in batch])
            return {'features': token_ids, 'targets': labels}
        else:
            return {'features': token_ids}

# %% [markdown]
# ## Build Model

# %%
from transformers import *
import torch
import torch.nn as nn
import torch.nn.functional as F


class QuestModel(nn.Module):
    def __init__(self, n_classes=2):
        super(QuestModel, self).__init__()
        self.model_name = 'QuestModel'
    
        self.bert_model = XLMRobertaModel.from_pretrained('xlm-roberta-large')

        self.fc = nn.Linear(1024, n_classes)

    def forward(self, ids):

        layers = self.bert_model(input_ids=ids)
        out = F.dropout(layers[0][:, 0, :], p=0.2, training=self.training)
        logit = self.fc(out)
        return logit

# %%
# bert_model = XLMRobertaModel.from_pretrained('xlm-roberta-base')

# %%
class BalancedSampler(torch.utils.data.sampler.Sampler):
    def __init__(self, dataset):
       
        self.toxic_inds = dataset.toxic_inds.copy()
        self.normal_inds = dataset.normal_inds.copy()
        
        self.num_samples = 2*max(len(self.toxic_inds), len(self.normal_inds))
        
        shfl(self.toxic_inds)
        shfl(self.normal_inds)
        
        self.inds = []
        for i in range(max(len(self.toxic_inds), len(self.normal_inds))):
            self.inds.append(self.normal_inds[i%len(self.normal_inds)])
            self.inds.append(self.toxic_inds[i%len(self.toxic_inds)])

    def __iter__(self):
        #print ('\tcalling Sampler:__iter__')
        return iter(self.inds)

    def __len__(self):
        #print ('\tcalling Sampler:__len__')
        return self.num_samples

# %%
def get_loaders(to_balance=True, shuffle_before=True):
    if SERVER:
        workers=1
    else:
        workers = 8    
    
    

    train_dataset = QuestDataset(df_train, train_mode=True)#, train_transforms=get_train_transforms())
    valid_dataset = QuestDataset(df_valid_3lng, train_mode=False)
    
       
    train_loader = DataLoader(
        train_dataset,
        num_workers=workers,
        sampler=BalancedSampler(train_dataset) if to_balance else None,
        batch_size=batch_size,
    )
    valid_loader = DataLoader(
        valid_dataset,
        num_workers=workers,
        batch_size=batch_size,
    )    
    
       
    loaders = {}
    loaders['train'] = train_loader
    loaders['valid'] = valid_loader
    
    
    for i in ['es', 'it', 'tr']:
        df = df_valid_3lng
        df = df[df['lang']==i]

        loaders['valid_'+ i] = DataLoader(
            QuestDataset(df, train_mode=False),
            num_workers=workers,
            batch_size=batch_size,
        )
    
    loaders['valid_same'] = DataLoader(
        QuestDataset(df_valid, train_mode=False),
        num_workers=workers,
        batch_size=batch_size,
    )
    return loaders

# %%
# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduce = reduce

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduce=False)
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduce=False)
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss

# %%
def freeze_until(net, param_name):
    found_name = False
    for name, params in net.named_parameters():
        if name == param_name:
            found_name = True
        params.requires_grad = found_name

def train_from_to(net, param_name_from, param_name_to):
    
    found_1_name = False
    found_2_name = False
    train_params = False
    
    for name, params in net.named_parameters():
        
        if not found_1_name:
            if name == param_name_from:
                train_params = True
                found_1_name = True
            
        elif not found_2_name:
            if name == param_name_to:
                train_params = False
                found_2_name = True
#         print(f'layer {name} will train? - {train_params}')
        params.requires_grad = train_params
        
# param_name = 'bert_model.encoder.layer.10.attention.self.query.weight'
param_name_from = 'bert_model.encoder.layer.8.attention.self.query.weight'
param_name_to = 'bert_model.encoder.layer.16.attention.self.query.weight'

CHECKPOINT = '/media/ssd/logs/jigsaw/js_v14_engbias/05072020_231432_lr1e-06/simple/checkpoints/best.pth'

project = "js_v14_engbias"
num_epochs = 300

group = datetime.now().strftime("%m%d%Y_%H%M%S")

    
if SERVER:
    group = f'{group}_srv'
    
if STRIDE > 1:
    group = f'{group}_str{STRIDE}'


gradient_accumulation_steps = 1

lr = 1e-6#1e-5#0.0001
group += f'_lr{lr}_2stage_balanced_smplr'

group = group.replace('.', '')

runner = SupervisedRunner(input_key=('features'), input_target_key=('targets'), output_key=('logits'))

experiment = 'simple'

torch.cuda.empty_cache()

logdir = f"{LOG_PATH}/{project}/{group}/{experiment}"

model = QuestModel(2)

checkpoint = torch.load(CHECKPOINT)#, map_location=device)   
model.load_state_dict(checkpoint['model_state_dict'])
del checkpoint

# freeze_until(model, param_name)
train_from_to(model, param_name_from, param_name_to)
# model = model.to(device)


loaders = get_loaders(to_balance=True)


t_total = len(loaders['train'])//gradient_accumulation_steps*num_epochs
warmup_proportion = 0.01
num_warmup_steps = t_total * warmup_proportion

#     criterion = torch.nn.BCEWithLogitsLoss()
criterion = FocalLoss(alpha=0.2, gamma=1.5, logits=True, reduce=True)
#     criterion = torch.nn.CrossEntropyLoss()
#     criterion = torch.nn.BCELoss()
optimizer = AdamW(model.parameters(), lr = lr)
#    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_warmup_steps, num_training_steps=t_total) 
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.25)
print(f'----------------Experiment: {experiment}')

runner.train(
    fp16=dict(opt_level="O1") ,
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    loaders=loaders,
    logdir=logdir,
    num_epochs=num_epochs,
    verbose=True,
    distributed=False if is_jupyter() else True,
    callbacks=[
        AlchemyLogger(
                token=token, # your Alchemy token
                project=project,
                experiment=experiment,
                group=group,
            ),
        MyAUCCallback()

    ],
    main_metric='auc/_mean',
    minimize_metric=False,
    
    #fp16={"opt_level": "O1"}

)
# Out:
# Here is 432056 samples, 134668 samples and 297388 samples
# Class balance is 0.31
# ----------------Experiment: simple
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Warning:  multi_tensor_applier fused unscale kernel is unavailable, possibly because apex was installed without --cuda_ext --cpp_ext. Using Python fallback.  Original ImportError was: ModuleNotFoundError("No module named 'amp_C'")
# 1/300 * Epoch (train):   0% 1/9294 [00:00<1:52:21,  1.38it/s, loss=0.034]
# /home/kb/jig_env/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning:
#
# size_average and reduce args will be deprecated, please use reduction='none' instead.
#
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning:
#
# This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# 1/300 * Epoch (train):   1% 126/9294 [00:38<45:55,  3.33it/s, loss=0.021]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 1/300 * Epoch (train):   1% 128/9294 [00:38<45:10,  3.38it/s, loss=0.023]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 1/300 * Epoch (train):   5% 502/9294 [02:31<44:25,  3.30it/s, loss=0.020]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 8192.0
# 1/300 * Epoch (train):  63% 5896/9294 [30:07<17:29,  3.24it/s, loss=0.011]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 1/300 * Epoch (train):  88% 8196/9294 [41:57<05:44,  3.19it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 1/300 * Epoch (train): 100% 9294/9294 [47:39<00:00,  3.25it/s, loss=0.031]
# 1/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.039]
# 1/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.037]
# 1/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.003]
# 1/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.77it/s, loss=0.015]
# 1/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.026]
# [2020-05-08 20:18:18,797]
# 1/300 * Epoch 1 (_base): lr=1.000e-06 | momentum=0.9000
# 1/300 * Epoch 1 (train): auc/_mean=0.9637 | auc/class_0=0.9637 | loss=0.0181
# 1/300 * Epoch 1 (valid): auc/_mean=0.9246 | auc/class_0=0.9246 | es_auc/_mean=0.9127 | es_auc/class_0=0.9127 | es_loss=0.0444 | it_auc/_mean=0.8827 | it_auc/class_0=0.8827 | it_loss=0.0508 | loss=0.0350 | same_auc/_mean=0.9735 | same_auc/class_0=0.9735 | same_loss=0.0164 | tr_auc/_mean=0.9752 | tr_auc/class_0=0.9752 | tr_loss=0.0127
# 1/300 * Epoch 1 (valid_es): auc/_mean=0.9127 | auc/class_0=0.9127 | loss=0.0444
# 1/300 * Epoch 1 (valid_it): auc/_mean=0.8827 | auc/class_0=0.8827 | loss=0.0508
# 1/300 * Epoch 1 (valid_tr): auc/_mean=0.9752 | auc/class_0=0.9752 | loss=0.0127
# 1/300 * Epoch 1 (valid_same): auc/_mean=0.9735 | auc/class_0=0.9735 | loss=0.0164
# 2/300 * Epoch (train):  42% 3949/9294 [20:15<27:27,  3.25it/s, loss=0.009]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 2/300 * Epoch (train):  88% 8169/9294 [41:56<05:48,  3.23it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 2/300 * Epoch (train): 100% 9294/9294 [47:44<00:00,  3.24it/s, loss=0.032]
# 2/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.035]
# 2/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.024]
# 2/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.002]
# 2/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.77it/s, loss=0.013]
# 2/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.031]
# [2020-05-08 21:09:04,770]
# 2/300 * Epoch 2 (_base): lr=1.000e-06 | momentum=0.9000
# 2/300 * Epoch 2 (train): auc/_mean=0.9741 | auc/class_0=0.9741 | loss=0.0152
# 2/300 * Epoch 2 (valid): auc/_mean=0.9289 | auc/class_0=0.9289 | es_auc/_mean=0.9183 | es_auc/class_0=0.9183 | es_loss=0.0402 | it_auc/_mean=0.8873 | it_auc/class_0=0.8873 | it_loss=0.0456 | loss=0.0314 | same_auc/_mean=0.9775 | same_auc/class_0=0.9775 | same_loss=0.0151 | tr_auc/_mean=0.9775 | tr_auc/class_0=0.9775 | tr_loss=0.0110
# 2/300 * Epoch 2 (valid_es): auc/_mean=0.9183 | auc/class_0=0.9183 | loss=0.0402
# 2/300 * Epoch 2 (valid_it): auc/_mean=0.8873 | auc/class_0=0.8873 | loss=0.0456
# 2/300 * Epoch 2 (valid_tr): auc/_mean=0.9775 | auc/class_0=0.9775 | loss=0.0110
# 2/300 * Epoch 2 (valid_same): auc/_mean=0.9775 | auc/class_0=0.9775 | loss=0.0151
# 3/300 * Epoch (train):  16% 1479/9294 [07:35<40:03,  3.25it/s, loss=0.016]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 3/300 * Epoch (train):  56% 5177/9294 [26:34<21:08,  3.25it/s, loss=0.015]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 3/300 * Epoch (train):  99% 9228/9294 [47:25<00:20,  3.24it/s, loss=0.015]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 3/300 * Epoch (train): 100% 9294/9294 [47:45<00:00,  3.24it/s, loss=0.016]
# 3/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.034]
# 3/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.85it/s, loss=0.016]
# 3/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.002]
# 3/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.77it/s, loss=0.011]
# 3/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.034]
# [2020-05-08 22:00:26,456]
# 3/300 * Epoch 3 (_base): lr=1.000e-06 | momentum=0.9000
# 3/300 * Epoch 3 (train): auc/_mean=0.9779 | auc/class_0=0.9779 | loss=0.0140
# 3/300 * Epoch 3 (valid): auc/_mean=0.9312 | auc/class_0=0.9312 | es_auc/_mean=0.9189 | es_auc/class_0=0.9189 | es_loss=0.0396 | it_auc/_mean=0.8901 | it_auc/class_0=0.8901 | it_loss=0.0443 | loss=0.0305 | same_auc/_mean=0.9800 | same_auc/class_0=0.9800 | same_loss=0.0143 | tr_auc/_mean=0.9797 | tr_auc/class_0=0.9797 | tr_loss=0.0100
# 3/300 * Epoch 3 (valid_es): auc/_mean=0.9189 | auc/class_0=0.9189 | loss=0.0396
# 3/300 * Epoch 3 (valid_it): auc/_mean=0.8901 | auc/class_0=0.8901 | loss=0.0443
# 3/300 * Epoch 3 (valid_tr): auc/_mean=0.9797 | auc/class_0=0.9797 | loss=0.0100
# 3/300 * Epoch 3 (valid_same): auc/_mean=0.9800 | auc/class_0=0.9800 | loss=0.0143
# 4/300 * Epoch (train):   1% 81/9294 [00:25<46:50,  3.28it/s, loss=0.021] Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 4/300 * Epoch (train):  27% 2548/9294 [13:04<34:36,  3.25it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 4/300 * Epoch (train):  47% 4374/9294 [22:27<25:16,  3.24it/s, loss=0.024]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 4/300 * Epoch (train):  90% 8399/9294 [43:07<04:38,  3.21it/s, loss=0.005]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 4/300 * Epoch (train): 100% 9294/9294 [47:45<00:00,  3.24it/s, loss=0.030]
# 4/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.034]
# 4/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.72it/s, loss=0.031]
# 4/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.76it/s, loss=0.002]
# 4/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.73it/s, loss=0.012]
# 4/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.16it/s, loss=0.033]
# [2020-05-08 22:51:50,204]
# 4/300 * Epoch 4 (_base): lr=1.000e-06 | momentum=0.9000
# 4/300 * Epoch 4 (train): auc/_mean=0.9806 | auc/class_0=0.9806 | loss=0.0131
# 4/300 * Epoch 4 (valid): auc/_mean=0.9312 | auc/class_0=0.9312 | es_auc/_mean=0.9205 | es_auc/class_0=0.9205 | es_loss=0.0399 | it_auc/_mean=0.8907 | it_auc/class_0=0.8907 | it_loss=0.0440 | loss=0.0303 | same_auc/_mean=0.9811 | same_auc/class_0=0.9811 | same_loss=0.0137 | tr_auc/_mean=0.9789 | tr_auc/class_0=0.9789 | tr_loss=0.0098
# 4/300 * Epoch 4 (valid_es): auc/_mean=0.9205 | auc/class_0=0.9205 | loss=0.0399
# 4/300 * Epoch 4 (valid_it): auc/_mean=0.8907 | auc/class_0=0.8907 | loss=0.0440
# 4/300 * Epoch 4 (valid_tr): auc/_mean=0.9789 | auc/class_0=0.9789 | loss=0.0098
# 4/300 * Epoch 4 (valid_same): auc/_mean=0.9811 | auc/class_0=0.9811 | loss=0.0137
# 5/300 * Epoch (train):  27% 2500/9294 [12:50<34:49,  3.25it/s, loss=0.024]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 5/300 * Epoch (train):  68% 6348/9294 [32:36<15:15,  3.22it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 5/300 * Epoch (train):  82% 7624/9294 [39:12<08:38,  3.22it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 5/300 * Epoch (train): 100% 9294/9294 [47:50<00:00,  3.24it/s, loss=0.010]
# 5/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  6.99it/s, loss=0.034]
# 5/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.76it/s, loss=0.025]
# 5/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.003]
# 5/300 * Epoch (valid_tr): 100% 47/47 [00:07<00:00,  6.67it/s, loss=0.011]
# 5/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.17it/s, loss=0.035]
# [2020-05-08 23:42:35,137]
# 5/300 * Epoch 5 (_base): lr=1.000e-06 | momentum=0.9000
# 5/300 * Epoch 5 (train): auc/_mean=0.9826 | auc/class_0=0.9826 | loss=0.0123
# 5/300 * Epoch 5 (valid): auc/_mean=0.9298 | auc/class_0=0.9298 | es_auc/_mean=0.9177 | es_auc/class_0=0.9177 | es_loss=0.0407 | it_auc/_mean=0.8905 | it_auc/class_0=0.8905 | it_loss=0.0454 | loss=0.0310 | same_auc/_mean=0.9819 | same_auc/class_0=0.9819 | same_loss=0.0138 | tr_auc/_mean=0.9783 | tr_auc/class_0=0.9783 | tr_loss=0.0098
# 5/300 * Epoch 5 (valid_es): auc/_mean=0.9177 | auc/class_0=0.9177 | loss=0.0407
# 5/300 * Epoch 5 (valid_it): auc/_mean=0.8905 | auc/class_0=0.8905 | loss=0.0454
# 5/300 * Epoch 5 (valid_tr): auc/_mean=0.9783 | auc/class_0=0.9783 | loss=0.0098
# 5/300 * Epoch 5 (valid_same): auc/_mean=0.9819 | auc/class_0=0.9819 | loss=0.0138
# 6/300 * Epoch (train):   5% 471/9294 [02:25<45:22,  3.24it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 6/300 * Epoch (train):  24% 2185/9294 [11:15<36:31,  3.24it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 6/300 * Epoch (train): 100% 9294/9294 [47:49<00:00,  3.24it/s, loss=0.014]
# 6/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.035]
# 6/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.026]
# 6/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.002]
# 6/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.012]
# 6/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.20it/s, loss=0.035]
# [2020-05-09 00:33:17,234]
# 6/300 * Epoch 6 (_base): lr=1.000e-06 | momentum=0.9000
# 6/300 * Epoch 6 (train): auc/_mean=0.9843 | auc/class_0=0.9843 | loss=0.0117
# 6/300 * Epoch 6 (valid): auc/_mean=0.9275 | auc/class_0=0.9275 | es_auc/_mean=0.9167 | es_auc/class_0=0.9167 | es_loss=0.0434 | it_auc/_mean=0.8890 | it_auc/class_0=0.8890 | it_loss=0.0482 | loss=0.0330 | same_auc/_mean=0.9827 | same_auc/class_0=0.9827 | same_loss=0.0140 | tr_auc/_mean=0.9754 | tr_auc/class_0=0.9754 | tr_loss=0.0106
# 6/300 * Epoch 6 (valid_es): auc/_mean=0.9167 | auc/class_0=0.9167 | loss=0.0434
# 6/300 * Epoch 6 (valid_it): auc/_mean=0.8890 | auc/class_0=0.8890 | loss=0.0482
# 6/300 * Epoch 6 (valid_tr): auc/_mean=0.9754 | auc/class_0=0.9754 | loss=0.0106
# 6/300 * Epoch 6 (valid_same): auc/_mean=0.9827 | auc/class_0=0.9827 | loss=0.0140
# 7/300 * Epoch (train):  12% 1159/9294 [05:57<41:44,  3.25it/s, loss=0.014]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 7/300 * Epoch (train):  21% 1977/9294 [10:09<37:34,  3.25it/s, loss=0.013]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 7/300 * Epoch (train):  24% 2186/9294 [11:13<36:28,  3.25it/s, loss=0.007]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 7/300 * Epoch (train):  68% 6350/9294 [32:37<15:09,  3.24it/s, loss=0.016]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 7/300 * Epoch (train):  79% 7306/9294 [37:32<10:14,  3.24it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 7/300 * Epoch (train): 100% 9294/9294 [47:47<00:00,  3.24it/s, loss=0.019]
# 7/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.035]
# 7/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.023]
# 7/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.78it/s, loss=0.003]
# 7/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.75it/s, loss=0.012]
# 7/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.037]
# [2020-05-09 01:23:56,400]
# 7/300 * Epoch 7 (_base): lr=2.500e-07 | momentum=0.9000
# 7/300 * Epoch 7 (train): auc/_mean=0.9860 | auc/class_0=0.9860 | loss=0.0109
# 7/300 * Epoch 7 (valid): auc/_mean=0.9261 | auc/class_0=0.9261 | es_auc/_mean=0.9146 | es_auc/class_0=0.9146 | es_loss=0.0436 | it_auc/_mean=0.8884 | it_auc/class_0=0.8884 | it_loss=0.0483 | loss=0.0330 | same_auc/_mean=0.9833 | same_auc/class_0=0.9833 | same_loss=0.0138 | tr_auc/_mean=0.9761 | tr_auc/class_0=0.9761 | tr_loss=0.0101
# 7/300 * Epoch 7 (valid_es): auc/_mean=0.9146 | auc/class_0=0.9146 | loss=0.0436
# 7/300 * Epoch 7 (valid_it): auc/_mean=0.8884 | auc/class_0=0.8884 | loss=0.0483
# 7/300 * Epoch 7 (valid_tr): auc/_mean=0.9761 | auc/class_0=0.9761 | loss=0.0101
# 7/300 * Epoch 7 (valid_same): auc/_mean=0.9833 | auc/class_0=0.9833 | loss=0.0138
# 8/300 * Epoch (train):  35% 3296/9294 [16:56<30:48,  3.24it/s, loss=0.017]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 8/300 * Epoch (train):  81% 7490/9294 [38:29<09:17,  3.24it/s, loss=0.013]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 8/300 * Epoch (train):  85% 7864/9294 [40:24<07:21,  3.24it/s, loss=0.016]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 8/300 * Epoch (train): 100% 9294/9294 [47:47<00:00,  3.24it/s, loss=0.007]
# 8/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.034]
# 8/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.028]
# 8/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.004]
# 8/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.77it/s, loss=0.013]
# 8/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.037]
# [2020-05-09 02:14:35,270]
# 8/300 * Epoch 8 (_base): lr=2.500e-07 | momentum=0.9000
# 8/300 * Epoch 8 (train): auc/_mean=0.9877 | auc/class_0=0.9877 | loss=0.0102
# 8/300 * Epoch 8 (valid): auc/_mean=0.9260 | auc/class_0=0.9260 | es_auc/_mean=0.9137 | es_auc/class_0=0.9137 | es_loss=0.0429 | it_auc/_mean=0.8882 | it_auc/class_0=0.8882 | it_loss=0.0467 | loss=0.0322 | same_auc/_mean=0.9837 | same_auc/class_0=0.9837 | same_loss=0.0135 | tr_auc/_mean=0.9764 | tr_auc/class_0=0.9764 | tr_loss=0.0100
# 8/300 * Epoch 8 (valid_es): auc/_mean=0.9137 | auc/class_0=0.9137 | loss=0.0429
# 8/300 * Epoch 8 (valid_it): auc/_mean=0.8882 | auc/class_0=0.8882 | loss=0.0467
# 8/300 * Epoch 8 (valid_tr): auc/_mean=0.9764 | auc/class_0=0.9764 | loss=0.0100
# 8/300 * Epoch 8 (valid_same): auc/_mean=0.9837 | auc/class_0=0.9837 | loss=0.0135
# 9/300 * Epoch (train):  16% 1475/9294 [07:34<40:09,  3.25it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 9/300 * Epoch (train):  47% 4379/9294 [22:29<25:19,  3.23it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 9/300 * Epoch (train):  67% 6248/9294 [32:06<15:42,  3.23it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 9/300 * Epoch (train): 100% 9294/9294 [47:47<00:00,  3.24it/s, loss=0.008]
# 9/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.04it/s, loss=0.033]
# 9/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.027]
# 9/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.86it/s, loss=0.004]
# 9/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.75it/s, loss=0.013]
# 9/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.18it/s, loss=0.036]
# [2020-05-09 03:05:16,990]
# 9/300 * Epoch 9 (_base): lr=2.500e-07 | momentum=0.9000
# 9/300 * Epoch 9 (train): auc/_mean=0.9880 | auc/class_0=0.9880 | loss=0.0101
# 9/300 * Epoch 9 (valid): auc/_mean=0.9263 | auc/class_0=0.9263 | es_auc/_mean=0.9138 | es_auc/class_0=0.9138 | es_loss=0.0424 | it_auc/_mean=0.8886 | it_auc/class_0=0.8886 | it_loss=0.0462 | loss=0.0318 | same_auc/_mean=0.9839 | same_auc/class_0=0.9839 | same_loss=0.0133 | tr_auc/_mean=0.9768 | tr_auc/class_0=0.9768 | tr_loss=0.0097
# 9/300 * Epoch 9 (valid_es): auc/_mean=0.9138 | auc/class_0=0.9138 | loss=0.0424
# 9/300 * Epoch 9 (valid_it): auc/_mean=0.8886 | auc/class_0=0.8886 | loss=0.0462
# 9/300 * Epoch 9 (valid_tr): auc/_mean=0.9768 | auc/class_0=0.9768 | loss=0.0097
# 9/300 * Epoch 9 (valid_same): auc/_mean=0.9839 | auc/class_0=0.9839 | loss=0.0133
# 10/300 * Epoch (train):  27% 2499/9294 [12:50<34:53,  3.25it/s, loss=0.014]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 10/300 * Epoch (train):  54% 5042/9294 [25:54<21:51,  3.24it/s, loss=0.008]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 10/300 * Epoch (train):  87% 8083/9294 [41:33<06:13,  3.24it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 10/300 * Epoch (train): 100% 9294/9294 [47:47<00:00,  3.24it/s, loss=0.005]
# 10/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.033]
# 10/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.019]
# 10/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.004]
# 10/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.013]
# 10/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.18it/s, loss=0.035]
# [2020-05-09 03:55:58,588]
# 10/300 * Epoch 10 (_base): lr=2.500e-07 | momentum=0.9000
# 10/300 * Epoch 10 (train): auc/_mean=0.9883 | auc/class_0=0.9883 | loss=0.0099
# 10/300 * Epoch 10 (valid): auc/_mean=0.9253 | auc/class_0=0.9253 | es_auc/_mean=0.9130 | es_auc/class_0=0.9130 | es_loss=0.0418 | it_auc/_mean=0.8880 | it_auc/class_0=0.8880 | it_loss=0.0460 | loss=0.0316 | same_auc/_mean=0.9838 | same_auc/class_0=0.9838 | same_loss=0.0133 | tr_auc/_mean=0.9761 | tr_auc/class_0=0.9761 | tr_loss=0.0098
# 10/300 * Epoch 10 (valid_es): auc/_mean=0.9130 | auc/class_0=0.9130 | loss=0.0418
# 10/300 * Epoch 10 (valid_it): auc/_mean=0.8880 | auc/class_0=0.8880 | loss=0.0460
# 10/300 * Epoch 10 (valid_tr): auc/_mean=0.9761 | auc/class_0=0.9761 | loss=0.0098
# 10/300 * Epoch 10 (valid_same): auc/_mean=0.9838 | auc/class_0=0.9838 | loss=0.0133
# 11/300 * Epoch (train):  10% 938/9294 [04:49<42:56,  3.24it/s, loss=0.006]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 11/300 * Epoch (train):  35% 3287/9294 [16:52<30:52,  3.24it/s, loss=0.007]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 11/300 * Epoch (train):  41% 3779/9294 [19:24<28:20,  3.24it/s, loss=0.004]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 11/300 * Epoch (train):  72% 6676/9294 [34:18<13:28,  3.24it/s, loss=0.008]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 11/300 * Epoch (train):  85% 7858/9294 [40:22<07:23,  3.24it/s, loss=0.007]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 11/300 * Epoch (train): 100% 9294/9294 [47:46<00:00,  3.24it/s, loss=0.009]
# 11/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.02it/s, loss=0.031]
# 11/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.019]
# 11/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.78it/s, loss=0.004]
# 11/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.014]
# 11/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.18it/s, loss=0.035]
# [2020-05-09 04:46:38,220]
# 11/300 * Epoch 11 (_base): lr=2.500e-07 | momentum=0.9000
# 11/300 * Epoch 11 (train): auc/_mean=0.9888 | auc/class_0=0.9888 | loss=0.0097
# 11/300 * Epoch 11 (valid): auc/_mean=0.9255 | auc/class_0=0.9255 | es_auc/_mean=0.9123 | es_auc/class_0=0.9123 | es_loss=0.0405 | it_auc/_mean=0.8883 | it_auc/class_0=0.8883 | it_loss=0.0445 | loss=0.0307 | same_auc/_mean=0.9841 | same_auc/class_0=0.9841 | same_loss=0.0130 | tr_auc/_mean=0.9758 | tr_auc/class_0=0.9758 | tr_loss=0.0099
# 11/300 * Epoch 11 (valid_es): auc/_mean=0.9123 | auc/class_0=0.9123 | loss=0.0405
# 11/300 * Epoch 11 (valid_it): auc/_mean=0.8883 | auc/class_0=0.8883 | loss=0.0445
# 11/300 * Epoch 11 (valid_tr): auc/_mean=0.9758 | auc/class_0=0.9758 | loss=0.0099
# 11/300 * Epoch 11 (valid_same): auc/_mean=0.9841 | auc/class_0=0.9841 | loss=0.0130
# 12/300 * Epoch (train):  72% 6734/9294 [34:35<13:09,  3.24it/s, loss=0.009]    Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 12/300 * Epoch (train):  85% 7874/9294 [40:27<07:17,  3.24it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 12/300 * Epoch (train): 100% 9294/9294 [47:46<00:00,  3.24it/s, loss=0.010]
# 12/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.032]
# 12/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.017]
# 12/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 12/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.75it/s, loss=0.014]
# 12/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.18it/s, loss=0.035]
# [2020-05-09 05:37:20,079]
# 12/300 * Epoch 12 (_base): lr=2.500e-07 | momentum=0.9000
# 12/300 * Epoch 12 (train): auc/_mean=0.9892 | auc/class_0=0.9892 | loss=0.0095
# 12/300 * Epoch 12 (valid): auc/_mean=0.9253 | auc/class_0=0.9253 | es_auc/_mean=0.9116 | es_auc/class_0=0.9116 | es_loss=0.0413 | it_auc/_mean=0.8880 | it_auc/class_0=0.8880 | it_loss=0.0451 | loss=0.0312 | same_auc/_mean=0.9842 | same_auc/class_0=0.9842 | same_loss=0.0130 | tr_auc/_mean=0.9762 | tr_auc/class_0=0.9762 | tr_loss=0.0099
# 12/300 * Epoch 12 (valid_es): auc/_mean=0.9116 | auc/class_0=0.9116 | loss=0.0413
# 12/300 * Epoch 12 (valid_it): auc/_mean=0.8880 | auc/class_0=0.8880 | loss=0.0451
# 12/300 * Epoch 12 (valid_tr): auc/_mean=0.9762 | auc/class_0=0.9762 | loss=0.0099
# 12/300 * Epoch 12 (valid_same): auc/_mean=0.9842 | auc/class_0=0.9842 | loss=0.0130
# 13/300 * Epoch (train):  26% 2415/9294 [12:24<35:24,  3.24it/s, loss=0.005]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 13/300 * Epoch (train):  50% 4629/9294 [23:46<23:50,  3.26it/s, loss=0.006]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 13/300 * Epoch (train):  73% 6790/9294 [34:52<13:43,  3.04it/s, loss=0.007]    Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 13/300 * Epoch (train): 100% 9294/9294 [47:46<00:00,  3.24it/s, loss=0.004]
# 13/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.032]
# 13/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.015]
# 13/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.004]
# 13/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.73it/s, loss=0.014]
# 13/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.036]
# [2020-05-09 06:27:58,422]
# 13/300 * Epoch 13 (_base): lr=6.250e-08 | momentum=0.9000
# 13/300 * Epoch 13 (train): auc/_mean=0.9896 | auc/class_0=0.9896 | loss=0.0093
# 13/300 * Epoch 13 (valid): auc/_mean=0.9249 | auc/class_0=0.9249 | es_auc/_mean=0.9106 | es_auc/class_0=0.9106 | es_loss=0.0417 | it_auc/_mean=0.8883 | it_auc/class_0=0.8883 | it_loss=0.0456 | loss=0.0316 | same_auc/_mean=0.9842 | same_auc/class_0=0.9842 | same_loss=0.0133 | tr_auc/_mean=0.9756 | tr_auc/class_0=0.9756 | tr_loss=0.0100
# 13/300 * Epoch 13 (valid_es): auc/_mean=0.9106 | auc/class_0=0.9106 | loss=0.0417
# 13/300 * Epoch 13 (valid_it): auc/_mean=0.8883 | auc/class_0=0.8883 | loss=0.0456
# 13/300 * Epoch 13 (valid_tr): auc/_mean=0.9756 | auc/class_0=0.9756 | loss=0.0100
# 13/300 * Epoch 13 (valid_same): auc/_mean=0.9842 | auc/class_0=0.9842 | loss=0.0133
# 14/300 * Epoch (train):  19% 1775/9294 [09:07<38:37,  3.24it/s, loss=0.003]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 14/300 * Epoch (train):  45% 4228/9294 [21:43<26:03,  3.24it/s, loss=0.014]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 14/300 * Epoch (train):  46% 4261/9294 [21:53<25:52,  3.24it/s, loss=0.009]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 14/300 * Epoch (train):  77% 7128/9294 [36:37<11:08,  3.24it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 14/300 * Epoch (train): 100% 9294/9294 [47:47<00:00,  3.24it/s, loss=0.012]
# 14/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.04it/s, loss=0.030]
# 14/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.009]
# 14/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 14/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.015]
# 14/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.033]
# [2020-05-09 07:18:38,386]
# 14/300 * Epoch 14 (_base): lr=6.250e-08 | momentum=0.9000
# 14/300 * Epoch 14 (train): auc/_mean=0.9898 | auc/class_0=0.9898 | loss=0.0092
# 14/300 * Epoch 14 (valid): auc/_mean=0.9251 | auc/class_0=0.9251 | es_auc/_mean=0.9109 | es_auc/class_0=0.9109 | es_loss=0.0393 | it_auc/_mean=0.8882 | it_auc/class_0=0.8882 | it_loss=0.0434 | loss=0.0301 | same_auc/_mean=0.9844 | same_auc/class_0=0.9844 | same_loss=0.0128 | tr_auc/_mean=0.9756 | tr_auc/class_0=0.9756 | tr_loss=0.0099
# 14/300 * Epoch 14 (valid_es): auc/_mean=0.9109 | auc/class_0=0.9109 | loss=0.0393
# 14/300 * Epoch 14 (valid_it): auc/_mean=0.8882 | auc/class_0=0.8882 | loss=0.0434
# 14/300 * Epoch 14 (valid_tr): auc/_mean=0.9756 | auc/class_0=0.9756 | loss=0.0099
# 14/300 * Epoch 14 (valid_same): auc/_mean=0.9844 | auc/class_0=0.9844 | loss=0.0128
# 15/300 * Epoch (train):   8% 706/9294 [03:37<44:05,  3.25it/s, loss=0.018]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 15/300 * Epoch (train):  41% 3841/9294 [19:43<28:01,  3.24it/s, loss=0.008]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 15/300 * Epoch (train):  80% 7479/9294 [38:25<09:19,  3.24it/s, loss=0.009]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 15/300 * Epoch (train): 100% 9294/9294 [47:46<00:00,  3.24it/s, loss=0.018]
# 15/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.029]
# 15/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.87it/s, loss=0.008]
# 15/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.005]
# 15/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.78it/s, loss=0.014]
# 15/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.033]
# [2020-05-09 08:09:16,688]
# 15/300 * Epoch 15 (_base): lr=6.250e-08 | momentum=0.9000
# 15/300 * Epoch 15 (train): auc/_mean=0.9899 | auc/class_0=0.9899 | loss=0.0091
# 15/300 * Epoch 15 (valid): auc/_mean=0.9251 | auc/class_0=0.9251 | es_auc/_mean=0.9109 | es_auc/class_0=0.9109 | es_loss=0.0388 | it_auc/_mean=0.8876 | it_auc/class_0=0.8876 | it_loss=0.0429 | loss=0.0297 | same_auc/_mean=0.9844 | same_auc/class_0=0.9844 | same_loss=0.0128 | tr_auc/_mean=0.9756 | tr_auc/class_0=0.9756 | tr_loss=0.0098
# 15/300 * Epoch 15 (valid_es): auc/_mean=0.9109 | auc/class_0=0.9109 | loss=0.0388
# 15/300 * Epoch 15 (valid_it): auc/_mean=0.8876 | auc/class_0=0.8876 | loss=0.0429
# 15/300 * Epoch 15 (valid_tr): auc/_mean=0.9756 | auc/class_0=0.9756 | loss=0.0098
# 15/300 * Epoch 15 (valid_same): auc/_mean=0.9844 | auc/class_0=0.9844 | loss=0.0128
# 16/300 * Epoch (train):  26% 2398/9294 [12:18<35:23,  3.25it/s, loss=0.002]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 16/300 * Epoch (train):  42% 3901/9294 [20:01<27:43,  3.24it/s, loss=0.003]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 16/300 * Epoch (train):  72% 6690/9294 [34:21<13:23,  3.24it/s, loss=0.005]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 16/300 * Epoch (train):  73% 6740/9294 [34:37<13:07,  3.24it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 16/300 * Epoch (train): 100% 9294/9294 [47:45<00:00,  3.24it/s, loss=0.010]
# 16/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.030]
# 16/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.009]
# 16/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.005]
# 16/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.015]
# 16/300 * Epoch (valid_same): 100% 751/751 [01:44<00:00,  7.19it/s, loss=0.032]
# [2020-05-09 08:59:54,296]
# 16/300 * Epoch 16 (_base): lr=6.250e-08 | momentum=0.9000
# 16/300 * Epoch 16 (train): auc/_mean=0.9900 | auc/class_0=0.9900 | loss=0.0091
# 16/300 * Epoch 16 (valid): auc/_mean=0.9247 | auc/class_0=0.9247 | es_auc/_mean=0.9107 | es_auc/class_0=0.9107 | es_loss=0.0394 | it_auc/_mean=0.8876 | it_auc/class_0=0.8876 | it_loss=0.0435 | loss=0.0301 | same_auc/_mean=0.9844 | same_auc/class_0=0.9844 | same_loss=0.0128 | tr_auc/_mean=0.9753 | tr_auc/class_0=0.9753 | tr_loss=0.0099
# 16/300 * Epoch 16 (valid_es): auc/_mean=0.9107 | auc/class_0=0.9107 | loss=0.0394
# 16/300 * Epoch 16 (valid_it): auc/_mean=0.8876 | auc/class_0=0.8876 | loss=0.0435
# 16/300 * Epoch 16 (valid_tr): auc/_mean=0.9753 | auc/class_0=0.9753 | loss=0.0099
# 16/300 * Epoch 16 (valid_same): auc/_mean=0.9844 | auc/class_0=0.9844 | loss=0.0128
# Early exiting
# 17/300 * Epoch (train):  36% 3362/9294 [17:16<30:28,  3.24it/s, loss=0.010]

# %%
# for name, params in model.named_parameters():
#     print(name)

# %% [markdown]
# ####

# %%
# for i, row in df_train.iterrows():
#     print(list(row.keys().values))
#     break

# %%
--
# Out:
#   File "<ipython-input-18-4071a1fba099>", line 1
#     --
#       ^
# SyntaxError: invalid syntax

# %%
CHECKPOINT = '/media/ssd/logs/jigsaw/js_v935_xlmrbtlg_10fr_pseudo/05_04_2020__14_16_58_lr1e-06_pseudo_train/simple/checkpoints/best.pth'

# %%
model = QuestModel(2)

checkpoint = torch.load(CHECKPOINT)#, map_location=device)   

model.load_state_dict(checkpoint['model_state_dict'])
del checkpoint

# %%
model = model.to(device)
_ = model.eval()

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')\
    .rename(columns={'content':'comment_text'})
ds = QuestDataset(df_test, train_mode=False, labeled=False)
loader = DataLoader(
        ds,
        num_workers=8,
        batch_size=batch_size,
    )

# %%
df_test.head()

# %%
y_pred = torch.zeros( len(ds), 2).to(device)

j = 0
with torch.no_grad():
    for data in tqdm(loader):
        x = data['features'].to(device)
        thish_batch_size = len(x)            
        
        
        y_pred[j:j+thish_batch_size] = model(x)
            
        j += thish_batch_size

# %%
from torch import sigmoid
y_pred_sigmoid = sigmoid(y_pred)

# %%
y_pred_sigmoid_one_np = y_pred_sigmoid.cpu().numpy()

# %%
df_sub['toxic'] = y_pred_sigmoid_one_np[:,1]

# %%
df_sub.to_csv('submission.csv', index=False)

# %%
df_sub
