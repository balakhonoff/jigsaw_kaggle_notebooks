# %%
# !pip install ./sacremoses/sacremoses-master/
# !pip install ./transformers/transformers-master/

STRIDE = 1
def is_jupyter():
    try:
        ipy_str = str(type(get_ipython()))
        if 'zmqshell' in ipy_str:
            return True
        
    except:
        return False

# %% [markdown]
# ### Required Imports
#
# I've added imports that will be used in training too

# %%
from sklearn.model_selection import train_test_split
import re
from random import shuffle as shfl
from auc import MyAUCCallback
from sklearn.utils import shuffle
from datetime import datetime
import pandas as pd
pd.set_option('display.max.columns', 500)
import numpy as np
import os
# os.environ['CUDA_VISIBLE_DEVICES'] ='3'
# os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda-10.1/lib64'
import matplotlib.pyplot as plt
import gc
from shutil import copyfile
from catalyst.dl import SupervisedRunner, AlchemyLogger, CriterionCallback
from catalyst.dl.callbacks.metrics import AUCCallback
from torch.utils.data import DataLoader, SubsetRandomSampler,Dataset
batch_size =64
token = "d1dd16f08d518293bcbeddd313b49aa4"
DATA_DIR = '/kaggle/input/jigsaw-multilingual-toxic-comment-classification/'
# Out:
# /home/kb/jig_env/lib/python3.7/site-packages/tqdm/std.py:666: FutureWarning: The Panel class is removed from pandas. Accessing it from the top-level namespace will also be removed in the next version
#   from pandas import Panel
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#
# /home/kb/jig_env/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning:
#
# numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject

# %%
if os.uname()[1] == 'kb-Z370P-D3':
    # desktop
    LOG_PATH = '/media/ssd/logs/jigsaw'
    SERVER = False
    print('Working on desktop')
elif os.uname()[1] == 'kb-server':
    # server
    LOG_PATH = '/home/kb/logs/jigsaw'
    SERVER = True
    print('Working on server')
else:
    raise Exception('which hostname???')
# Out:
# Working on desktop

# %%
df_train = None
df_valid = None
for lang in ['es', 'tr', 'it', 'ru', 'pt', 'fr']:
    df_temp = pd.read_csv(f'/kaggle/input/jigsaw-multilingual-toxic-comment-classification/google/jigsaw-toxic-comment-train-google-{lang}-cleaned.csv')
    
    df_temp = pd.concat([
        df_temp[['comment_text', 'toxic']].query('toxic==1'),
        df_temp[['comment_text', 'toxic']].query('toxic==0').sample(n=21378, random_state=0)
    ])

    df_train_lng, df_valid_lng = train_test_split(df_temp, random_state=12345, 
                                         stratify=df_temp.toxic.values, test_size=0.1)
    
    if df_train is None:
        df_train = df_train_lng.copy()
        df_valid = df_valid_lng.copy()
        
    else:
        df_train = df_train.append(df_train_lng[df_train.columns]).reset_index(drop=True)
        df_valid = df_valid.append(df_valid_lng[df_train.columns]).reset_index(drop=True)
        
    print(len(df_train))
    
df_temp = pd.read_csv(f'/kaggle/input/jigsaw-multilingual-toxic-comment-classification/jigsaw-toxic-comment-train.csv')
df_temp = pd.concat([
        df_temp[['comment_text', 'toxic']].query('toxic==1'),
        df_temp[['comment_text', 'toxic']].query('toxic==0').sample(n=21378, random_state=0)
    ])
df_train_lng, df_valid_lng = train_test_split(df_temp, random_state=12345, 
                                         stratify=df_temp.toxic.values, test_size=0.1)
df_train = df_train.append(df_train_lng[df_train.columns]).reset_index(drop=True)
df_valid = df_valid.append(df_valid_lng[df_train.columns]).reset_index(drop=True)
print(len(df_train))
# Out:
# 38476
# 76956
# 115436
# 153902
# 192382
# 230862
# 269347

# %%
df_valid_3lng = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/validation.csv')
sub = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/sample_submission.csv')

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')\
    .rename(columns={'content':'comment_text'})

# %%
target_column = 'toxic'

# %% [markdown]
# ### Define dataset

# %%
# 7from scipy.stats import spearmanr
from sklearn.model_selection import train_test_split, cross_val_score, KFold
import time
from torch.optim import lr_scheduler

import torch
from tqdm import tqdm
#import torch.utils.data as data
from torchvision import datasets, models, transforms
from transformers import *
import random
from math import floor, ceil
from sklearn.model_selection import GroupKFold

MAX_LEN = 96#192#192#512
SEP_TOKEN_ID = 102

class QuestDataset(torch.utils.data.Dataset):
    def __init__(self, df, train_mode=True, labeled=True, train_transforms=None):
        
        self.train_transforms = train_transforms
        self.df = df
        if train_mode:
            self.labels = df.toxic.values
            self.toxic_inds = np.where(self.labels==1)[0]
            self.normal_inds = np.where(self.labels==0)[0]            
            
            
            print(f'Here is {len(self.labels)} samples, {len(self.toxic_inds)} samples and {len(self.normal_inds)} samples')
            print(f'Class balance is {len(self.toxic_inds)/len(self.labels):.2f}')
            
        self.train_mode = train_mode
        self.labeled = labeled

        self.tokenizer = XLMRobertaTokenizer.from_pretrained('xlm-roberta-large')#, 


    def __getitem__(self, index):
        row = self.df.iloc[index]
        token_ids = self.get_token_ids(row)
        
        if self.labeled:
            labels = self.get_label(row)
            return {'features': token_ids, 'targets': labels}

        else:
            return {'features': token_ids}

    def __len__(self):
        return len(self.df)


        
    def get_token_ids(self, row):
        
        text = row.comment_text
        if self.train_transforms:
            lang = 'en' if 'lang' not in list(row.keys().values) else row.lang
            text, _ = self.train_transforms(data=(row.comment_text, lang))['data']
        
        if self.train_mode:
            token_ids = self.tokenizer.encode(text, max_length=1024)
            if len(token_ids) < MAX_LEN:
                ids = torch.tensor(token_ids + [0] * (MAX_LEN - len(token_ids)))
            else:
                ind_beg = random.randint(0, len(token_ids)-MAX_LEN)
                ids = torch.tensor(token_ids[ind_beg:ind_beg+MAX_LEN])
        else:
            token_ids = self.tokenizer.encode(text, max_length=MAX_LEN)
            if len(token_ids) < MAX_LEN:
                ids = torch.tensor(token_ids + [0] * (MAX_LEN - len(token_ids)))
            else:
                ids = torch.tensor(token_ids[:MAX_LEN])

        return ids

    def get_label(self, row):
        label = np.round(row[target_column])
        return torch.tensor([1-label, label]).float()
    
    def collate_fn(self, batch):
        token_ids = torch.stack([x[0] for x in batch])

        if self.labeled:
            labels = torch.stack([x[1] for x in batch])
            return {'features': token_ids, 'targets': labels}
        else:
            return {'features': token_ids}

# %% [markdown]
# ## Build Model

# %%
from transformers import *
import torch
import torch.nn as nn
import torch.nn.functional as F


class QuestModel(nn.Module):
    def __init__(self, n_classes=2):
        super(QuestModel, self).__init__()
        self.model_name = 'QuestModel'
    
        self.bert_model = XLMRobertaModel.from_pretrained('xlm-roberta-large')

        self.fc = nn.Linear(1024, n_classes)

    def forward(self, ids):

        layers = self.bert_model(input_ids=ids)
        out = F.dropout(layers[0][:, 0, :], p=0.2, training=self.training)
        logit = self.fc(out)
        return logit

# %%
# bert_model = XLMRobertaModel.from_pretrained('xlm-roberta-base')

# %%
class BalancedSampler(torch.utils.data.sampler.Sampler):
    def __init__(self, dataset):
       
        self.toxic_inds = dataset.toxic_inds.copy()
        self.normal_inds = dataset.normal_inds.copy()
        
        self.num_samples = 2*max(len(self.toxic_inds), len(self.normal_inds))
        
        shfl(self.toxic_inds)
        shfl(self.normal_inds)
        
        self.inds = []
        for i in range(max(len(self.toxic_inds), len(self.normal_inds))):
            self.inds.append(self.normal_inds[i%len(self.normal_inds)])
            self.inds.append(self.toxic_inds[i%len(self.toxic_inds)])

    def __iter__(self):
        #print ('\tcalling Sampler:__iter__')
        return iter(self.inds)

    def __len__(self):
        #print ('\tcalling Sampler:__len__')
        return self.num_samples

# %%
def get_loaders(to_balance=True, shuffle_before=True):
    if SERVER:
        workers=1
    else:
        workers = 8    
    
    

    train_dataset = QuestDataset(df_train, train_mode=True)#, train_transforms=get_train_transforms())
    valid_dataset = QuestDataset(df_valid_3lng, train_mode=False)
    
       
    train_loader = DataLoader(
        train_dataset,
        num_workers=workers,
        sampler=None,
        batch_size=batch_size,
    )
    valid_loader = DataLoader(
        valid_dataset,
        num_workers=workers,
        batch_size=batch_size,
    )    
    
       
    loaders = {}
    loaders['train'] = train_loader
    loaders['valid'] = valid_loader
    
    
    for i in ['es', 'it', 'tr']:
        df = df_valid_3lng
        df = df[df['lang']==i]

        loaders['valid_'+ i] = DataLoader(
            QuestDataset(df, train_mode=False),
            num_workers=workers,
            batch_size=batch_size,
        )
    
    loaders['valid_same'] = DataLoader(
        QuestDataset(df_valid, train_mode=False),
        num_workers=workers,
        batch_size=batch_size,
    )
    return loaders

# %%
# Detect if we have a GPU available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2, logits=False, reduce=True):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.logits = logits
        self.reduce = reduce

    def forward(self, inputs, targets):
        if self.logits:
            BCE_loss = F.binary_cross_entropy_with_logits(inputs, targets, reduce=False)
        else:
            BCE_loss = F.binary_cross_entropy(inputs, targets, reduce=False)
        pt = torch.exp(-BCE_loss)
        F_loss = self.alpha * (1-pt)**self.gamma * BCE_loss

        if self.reduce:
            return torch.mean(F_loss)
        else:
            return F_loss

# %%
def freeze_until(net, param_name):
    found_name = False
    for name, params in net.named_parameters():
        if name == param_name:
            found_name = True
        params.requires_grad = found_name

def train_from_to(net, param_name_from, param_name_to):
    
    found_1_name = False
    found_2_name = False
    train_params = False
    
    for name, params in net.named_parameters():
        
        if not found_1_name:
            if name == param_name_from:
                train_params = True
                found_1_name = True
            
        elif not found_2_name:
            if name == param_name_to:
                train_params = False
                found_2_name = True
#         print(f'layer {name} will train? - {train_params}')
        params.requires_grad = train_params
        
# param_name = 'bert_model.encoder.layer.10.attention.self.query.weight'
param_name_from = 'bert_model.encoder.layer.8.attention.self.query.weight'
param_name_to = 'bert_model.encoder.layer.16.attention.self.query.weight'

CHECKPOINT = '/media/ssd/logs/jigsaw/js_v14_engbias/05072020_231432_lr1e-06/simple/checkpoints/best.pth'

project = "js_v14_engbias"
num_epochs = 300

group = datetime.now().strftime("%m%d%Y_%H%M%S")

    
if SERVER:
    group = f'{group}_srv'
    
if STRIDE > 1:
    group = f'{group}_str{STRIDE}'


gradient_accumulation_steps = 1

lr = 1e-6#1e-5#0.0001
group += f'_lr{lr}_2stage'

group = group.replace('.', '')

runner = SupervisedRunner(input_key=('features'), input_target_key=('targets'), output_key=('logits'))

experiment = 'simple'

torch.cuda.empty_cache()

logdir = f"{LOG_PATH}/{project}/{group}/{experiment}"

model = QuestModel(2)

checkpoint = torch.load(CHECKPOINT)#, map_location=device)   
model.load_state_dict(checkpoint['model_state_dict'])
del checkpoint

# freeze_until(model, param_name)
train_from_to(model, param_name_from, param_name_to)
# model = model.to(device)


loaders = get_loaders(to_balance=True)


t_total = len(loaders['train'])//gradient_accumulation_steps*num_epochs
warmup_proportion = 0.01
num_warmup_steps = t_total * warmup_proportion

#     criterion = torch.nn.BCEWithLogitsLoss()
criterion = FocalLoss(alpha=0.2, gamma=1.5, logits=True, reduce=True)
#     criterion = torch.nn.CrossEntropyLoss()
#     criterion = torch.nn.BCELoss()
optimizer = AdamW(model.parameters(), lr = lr)
#    scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=num_warmup_steps, num_training_steps=t_total) 
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, patience=5, factor=0.25)
print(f'----------------Experiment: {experiment}')

runner.train(
    fp16=dict(opt_level="O1") ,
    model=model,
    criterion=criterion,
    optimizer=optimizer,
    scheduler=scheduler,
    loaders=loaders,
    logdir=logdir,
    num_epochs=num_epochs,
    verbose=True,
    distributed=False if is_jupyter() else True,
    callbacks=[
        AlchemyLogger(
                token=token, # your Alchemy token
                project=project,
                experiment=experiment,
                group=group,
            ),
        MyAUCCallback()

    ],
    main_metric='auc/_mean',
    minimize_metric=False,
    
    #fp16={"opt_level": "O1"}

)
# Out:
# Here is 269347 samples, 134667 samples and 134680 samples
# Class balance is 0.50
# ----------------Experiment: simple
# Selected optimization level O1:  Insert automatic casts around Pytorch functions and Tensor methods.
#
# Defaults for this optimization level are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Processing user overrides (additional kwargs that are not None)...
# After processing overrides, optimization options are:
# enabled                : True
# opt_level              : O1
# cast_model_type        : None
# patch_torch_functions  : True
# keep_batchnorm_fp32    : None
# master_weights         : None
# loss_scale             : dynamic
# Warning:  multi_tensor_applier fused unscale kernel is unavailable, possibly because apex was installed without --cuda_ext --cpp_ext. Using Python fallback.  Original ImportError was: ModuleNotFoundError("No module named 'amp_C'")
# 1/300 * Epoch (train):   0% 1/4209 [00:00<53:50,  1.30it/s, loss=0.038]
# /home/kb/jig_env/lib/python3.7/site-packages/torch/nn/_reduction.py:43: UserWarning:
#
# size_average and reduce args will be deprecated, please use reduction='none' instead.
#
# /pytorch/torch/csrc/utils/python_arg_parser.cpp:756: UserWarning:
#
# This overload of add_ is deprecated:
# 	add_(Number alpha, Tensor other)
# Consider using one of the following signatures instead:
# 	add_(Tensor other, *, Number alpha)
# 1/300 * Epoch (train):   0% 8/4209 [00:02<23:41,  2.96it/s, loss=0.023]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 1/300 * Epoch (train):  15% 643/4209 [03:15<18:11,  3.27it/s, loss=0.025]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 1/300 * Epoch (train):  31% 1297/4209 [06:36<14:52,  3.26it/s, loss=0.022]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 8192.0
# 1/300 * Epoch (train):  45% 1886/4209 [09:36<11:52,  3.26it/s, loss=0.024]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 4096.0
# 1/300 * Epoch (train): 100% 4209/4209 [21:28<00:00,  3.27it/s, loss=0.011]
# 1/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.025]
# 1/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.76it/s, loss=0.012]
# 1/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.76it/s, loss=0.003]
# 1/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.009]
# 1/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.19it/s, loss=0.029]
# [2020-05-08 00:29:46,586]
# 1/300 * Epoch 1 (_base): lr=1.000e-06 | momentum=0.9000
# 1/300 * Epoch 1 (train): auc/_mean=0.9410 | auc/class_0=0.9410 | loss=0.0232
# 1/300 * Epoch 1 (valid): auc/_mean=0.9248 | auc/class_0=0.9248 | es_auc/_mean=0.9092 | es_auc/class_0=0.9092 | es_loss=0.0284 | it_auc/_mean=0.8837 | it_auc/class_0=0.8837 | it_loss=0.0342 | loss=0.0233 | same_auc/_mean=0.9542 | same_auc/class_0=0.9542 | same_loss=0.0214 | tr_auc/_mean=0.9793 | tr_auc/class_0=0.9793 | tr_loss=0.0092
# 1/300 * Epoch 1 (valid_es): auc/_mean=0.9092 | auc/class_0=0.9092 | loss=0.0284
# 1/300 * Epoch 1 (valid_it): auc/_mean=0.8837 | auc/class_0=0.8837 | loss=0.0342
# 1/300 * Epoch 1 (valid_tr): auc/_mean=0.9793 | auc/class_0=0.9793 | loss=0.0092
# 1/300 * Epoch 1 (valid_same): auc/_mean=0.9542 | auc/class_0=0.9542 | loss=0.0214
# 2/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.016]
# 2/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.029]
# 2/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.78it/s, loss=0.016]
# 2/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.76it/s, loss=0.003]
# 2/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.73it/s, loss=0.009]
# 2/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.16it/s, loss=0.028]
# [2020-05-08 00:53:43,688]
# 2/300 * Epoch 2 (_base): lr=1.000e-06 | momentum=0.9000
# 2/300 * Epoch 2 (train): auc/_mean=0.9538 | auc/class_0=0.9538 | loss=0.0204
# 2/300 * Epoch 2 (valid): auc/_mean=0.9276 | auc/class_0=0.9276 | es_auc/_mean=0.9112 | es_auc/class_0=0.9112 | es_loss=0.0312 | it_auc/_mean=0.8868 | it_auc/class_0=0.8868 | it_loss=0.0366 | loss=0.0247 | same_auc/_mean=0.9608 | same_auc/class_0=0.9608 | same_loss=0.0194 | tr_auc/_mean=0.9819 | tr_auc/class_0=0.9819 | tr_loss=0.0085
# 2/300 * Epoch 2 (valid_es): auc/_mean=0.9112 | auc/class_0=0.9112 | loss=0.0312
# 2/300 * Epoch 2 (valid_it): auc/_mean=0.8868 | auc/class_0=0.8868 | loss=0.0366
# 2/300 * Epoch 2 (valid_tr): auc/_mean=0.9819 | auc/class_0=0.9819 | loss=0.0085
# 2/300 * Epoch 2 (valid_same): auc/_mean=0.9608 | auc/class_0=0.9608 | loss=0.0194
# 3/300 * Epoch (train):  36% 1521/4209 [07:48<13:47,  3.25it/s, loss=0.017]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 3/300 * Epoch (train):  98% 4120/4209 [21:08<00:27,  3.25it/s, loss=0.026]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 3/300 * Epoch (train): 100% 4209/4209 [21:36<00:00,  3.25it/s, loss=0.020]
# 3/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.027]
# 3/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.010]
# 3/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.003]
# 3/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.73it/s, loss=0.008]
# 3/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.027]
# [2020-05-08 01:18:20,978]
# 3/300 * Epoch 3 (_base): lr=1.000e-06 | momentum=0.9000
# 3/300 * Epoch 3 (train): auc/_mean=0.9598 | auc/class_0=0.9598 | loss=0.0190
# 3/300 * Epoch 3 (valid): auc/_mean=0.9288 | auc/class_0=0.9288 | es_auc/_mean=0.9120 | es_auc/class_0=0.9120 | es_loss=0.0314 | it_auc/_mean=0.8879 | it_auc/class_0=0.8879 | it_loss=0.0369 | loss=0.0248 | same_auc/_mean=0.9632 | same_auc/class_0=0.9632 | same_loss=0.0187 | tr_auc/_mean=0.9829 | tr_auc/class_0=0.9829 | tr_loss=0.0081
# 3/300 * Epoch 3 (valid_es): auc/_mean=0.9120 | auc/class_0=0.9120 | loss=0.0314
# 3/300 * Epoch 3 (valid_it): auc/_mean=0.8879 | auc/class_0=0.8879 | loss=0.0369
# 3/300 * Epoch 3 (valid_tr): auc/_mean=0.9829 | auc/class_0=0.9829 | loss=0.0081
# 3/300 * Epoch 3 (valid_same): auc/_mean=0.9632 | auc/class_0=0.9632 | loss=0.0187
# 4/300 * Epoch (train):  56% 2363/4209 [12:06<09:28,  3.25it/s, loss=0.020]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 4/300 * Epoch (train):  93% 3922/4209 [20:07<01:28,  3.25it/s, loss=0.012]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 4/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.010]
# 4/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.03it/s, loss=0.025]
# 4/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.008]
# 4/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 4/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.008]
# 4/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.17it/s, loss=0.023]
# [2020-05-08 01:42:54,225]
# 4/300 * Epoch 4 (_base): lr=1.000e-06 | momentum=0.9000
# 4/300 * Epoch 4 (train): auc/_mean=0.9636 | auc/class_0=0.9636 | loss=0.0181
# 4/300 * Epoch 4 (valid): auc/_mean=0.9322 | auc/class_0=0.9322 | es_auc/_mean=0.9167 | es_auc/class_0=0.9167 | es_loss=0.0282 | it_auc/_mean=0.8922 | it_auc/class_0=0.8922 | it_loss=0.0332 | loss=0.0224 | same_auc/_mean=0.9661 | same_auc/class_0=0.9661 | same_loss=0.0188 | tr_auc/_mean=0.9846 | tr_auc/class_0=0.9846 | tr_loss=0.0076
# 4/300 * Epoch 4 (valid_es): auc/_mean=0.9167 | auc/class_0=0.9167 | loss=0.0282
# 4/300 * Epoch 4 (valid_it): auc/_mean=0.8922 | auc/class_0=0.8922 | loss=0.0332
# 4/300 * Epoch 4 (valid_tr): auc/_mean=0.9846 | auc/class_0=0.9846 | loss=0.0076
# 4/300 * Epoch 4 (valid_same): auc/_mean=0.9661 | auc/class_0=0.9661 | loss=0.0188
# 5/300 * Epoch (train):  54% 2275/4209 [11:38<09:55,  3.25it/s, loss=0.011]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 5/300 * Epoch (train):  76% 3198/4209 [16:22<05:11,  3.25it/s, loss=0.014]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 8192.0
# 5/300 * Epoch (train): 100% 4209/4209 [21:34<00:00,  3.25it/s, loss=0.013]
# 5/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  6.99it/s, loss=0.023]
# 5/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.006]
# 5/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.004]
# 5/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.007]
# 5/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.023]
# [2020-05-08 02:07:26,402]
# 5/300 * Epoch 5 (_base): lr=1.000e-06 | momentum=0.9000
# 5/300 * Epoch 5 (train): auc/_mean=0.9665 | auc/class_0=0.9665 | loss=0.0174
# 5/300 * Epoch 5 (valid): auc/_mean=0.9335 | auc/class_0=0.9335 | es_auc/_mean=0.9179 | es_auc/class_0=0.9179 | es_loss=0.0283 | it_auc/_mean=0.8947 | it_auc/class_0=0.8947 | it_loss=0.0322 | loss=0.0221 | same_auc/_mean=0.9676 | same_auc/class_0=0.9676 | same_loss=0.0182 | tr_auc/_mean=0.9854 | tr_auc/class_0=0.9854 | tr_loss=0.0074
# 5/300 * Epoch 5 (valid_es): auc/_mean=0.9179 | auc/class_0=0.9179 | loss=0.0283
# 5/300 * Epoch 5 (valid_it): auc/_mean=0.8947 | auc/class_0=0.8947 | loss=0.0322
# 5/300 * Epoch 5 (valid_tr): auc/_mean=0.9854 | auc/class_0=0.9854 | loss=0.0074
# 5/300 * Epoch 5 (valid_same): auc/_mean=0.9676 | auc/class_0=0.9676 | loss=0.0182
# 6/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.011]
# 6/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.02it/s, loss=0.022]
# 6/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.005]
# 6/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.004]
# 6/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.007]
# 6/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.022]
# [2020-05-08 02:31:58,401]
# 6/300 * Epoch 6 (_base): lr=1.000e-06 | momentum=0.9000
# 6/300 * Epoch 6 (train): auc/_mean=0.9691 | auc/class_0=0.9691 | loss=0.0167
# 6/300 * Epoch 6 (valid): auc/_mean=0.9335 | auc/class_0=0.9335 | es_auc/_mean=0.9176 | es_auc/class_0=0.9176 | es_loss=0.0283 | it_auc/_mean=0.8963 | it_auc/class_0=0.8963 | it_loss=0.0324 | loss=0.0221 | same_auc/_mean=0.9683 | same_auc/class_0=0.9683 | same_loss=0.0182 | tr_auc/_mean=0.9853 | tr_auc/class_0=0.9853 | tr_loss=0.0073
# 6/300 * Epoch 6 (valid_es): auc/_mean=0.9176 | auc/class_0=0.9176 | loss=0.0283
# 6/300 * Epoch 6 (valid_it): auc/_mean=0.8963 | auc/class_0=0.8963 | loss=0.0324
# 6/300 * Epoch 6 (valid_tr): auc/_mean=0.9853 | auc/class_0=0.9853 | loss=0.0073
# 6/300 * Epoch 6 (valid_same): auc/_mean=0.9683 | auc/class_0=0.9683 | loss=0.0182
# 7/300 * Epoch (train):   1% 34/4209 [00:10<21:07,  3.30it/s, loss=0.013]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 16384.0
# 7/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.008]
# 7/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.02it/s, loss=0.023]
# 7/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.004]
# 7/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.005]
# 7/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.80it/s, loss=0.008]
# 7/300 * Epoch (valid_same): 100% 468/468 [01:04<00:00,  7.21it/s, loss=0.021]
# [2020-05-08 02:56:32,315]
# 7/300 * Epoch 7 (_base): lr=2.500e-07 | momentum=0.9000
# 7/300 * Epoch 7 (train): auc/_mean=0.9710 | auc/class_0=0.9710 | loss=0.0161
# 7/300 * Epoch 7 (valid): auc/_mean=0.9328 | auc/class_0=0.9328 | es_auc/_mean=0.9180 | es_auc/class_0=0.9180 | es_loss=0.0282 | it_auc/_mean=0.8938 | it_auc/class_0=0.8938 | it_loss=0.0326 | loss=0.0222 | same_auc/_mean=0.9707 | same_auc/class_0=0.9707 | same_loss=0.0175 | tr_auc/_mean=0.9849 | tr_auc/class_0=0.9849 | tr_loss=0.0074
# 7/300 * Epoch 7 (valid_es): auc/_mean=0.9180 | auc/class_0=0.9180 | loss=0.0282
# 7/300 * Epoch 7 (valid_it): auc/_mean=0.8938 | auc/class_0=0.8938 | loss=0.0326
# 7/300 * Epoch 7 (valid_tr): auc/_mean=0.9849 | auc/class_0=0.9849 | loss=0.0074
# 7/300 * Epoch 7 (valid_same): auc/_mean=0.9707 | auc/class_0=0.9707 | loss=0.0175
# 8/300 * Epoch (train):   9% 385/4209 [01:58<19:33,  3.26it/s, loss=0.020]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 8/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.008]
# 8/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.04it/s, loss=0.024]
# 8/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.85it/s, loss=0.006]
# 8/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.004]
# 8/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.008]
# 8/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.19it/s, loss=0.023]
# [2020-05-08 03:20:20,928]
# 8/300 * Epoch 8 (_base): lr=2.500e-07 | momentum=0.9000
# 8/300 * Epoch 8 (train): auc/_mean=0.9730 | auc/class_0=0.9730 | loss=0.0156
# 8/300 * Epoch 8 (valid): auc/_mean=0.9331 | auc/class_0=0.9331 | es_auc/_mean=0.9195 | es_auc/class_0=0.9195 | es_loss=0.0291 | it_auc/_mean=0.8941 | it_auc/class_0=0.8941 | it_loss=0.0336 | loss=0.0228 | same_auc/_mean=0.9715 | same_auc/class_0=0.9715 | same_loss=0.0170 | tr_auc/_mean=0.9843 | tr_auc/class_0=0.9843 | tr_loss=0.0075
# 8/300 * Epoch 8 (valid_es): auc/_mean=0.9195 | auc/class_0=0.9195 | loss=0.0291
# 8/300 * Epoch 8 (valid_it): auc/_mean=0.8941 | auc/class_0=0.8941 | loss=0.0336
# 8/300 * Epoch 8 (valid_tr): auc/_mean=0.9843 | auc/class_0=0.9843 | loss=0.0075
# 8/300 * Epoch 8 (valid_same): auc/_mean=0.9715 | auc/class_0=0.9715 | loss=0.0170
# 9/300 * Epoch (train):  38% 1585/4209 [08:06<13:22,  3.27it/s, loss=0.018]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 9/300 * Epoch (train): 100% 4209/4209 [21:33<00:00,  3.25it/s, loss=0.013]
# 9/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.023]
# 9/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.005]
# 9/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.004]
# 9/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.77it/s, loss=0.007]
# 9/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.19it/s, loss=0.022]
# [2020-05-08 03:44:08,158]
# 9/300 * Epoch 9 (_base): lr=2.500e-07 | momentum=0.9000
# 9/300 * Epoch 9 (train): auc/_mean=0.9734 | auc/class_0=0.9734 | loss=0.0154
# 9/300 * Epoch 9 (valid): auc/_mean=0.9332 | auc/class_0=0.9332 | es_auc/_mean=0.9194 | es_auc/class_0=0.9194 | es_loss=0.0291 | it_auc/_mean=0.8942 | it_auc/class_0=0.8942 | it_loss=0.0333 | loss=0.0227 | same_auc/_mean=0.9716 | same_auc/class_0=0.9716 | same_loss=0.0169 | tr_auc/_mean=0.9845 | tr_auc/class_0=0.9845 | tr_loss=0.0075
# 9/300 * Epoch 9 (valid_es): auc/_mean=0.9194 | auc/class_0=0.9194 | loss=0.0291
# 9/300 * Epoch 9 (valid_it): auc/_mean=0.8942 | auc/class_0=0.8942 | loss=0.0333
# 9/300 * Epoch 9 (valid_tr): auc/_mean=0.9845 | auc/class_0=0.9845 | loss=0.0075
# 9/300 * Epoch 9 (valid_same): auc/_mean=0.9716 | auc/class_0=0.9716 | loss=0.0169
# 10/300 * Epoch (train):  22% 905/4209 [04:37<16:53,  3.26it/s, loss=0.023]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 10/300 * Epoch (train):  94% 3949/4209 [20:12<01:19,  3.26it/s, loss=0.013]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 10/300 * Epoch (train): 100% 4209/4209 [21:32<00:00,  3.26it/s, loss=0.006]
# 10/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.025]
# 10/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.008]
# 10/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.004]
# 10/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.79it/s, loss=0.008]
# 10/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.20it/s, loss=0.022]
# [2020-05-08 04:07:53,029]
# 10/300 * Epoch 10 (_base): lr=2.500e-07 | momentum=0.9000
# 10/300 * Epoch 10 (train): auc/_mean=0.9744 | auc/class_0=0.9744 | loss=0.0151
# 10/300 * Epoch 10 (valid): auc/_mean=0.9331 | auc/class_0=0.9331 | es_auc/_mean=0.9195 | es_auc/class_0=0.9195 | es_loss=0.0307 | it_auc/_mean=0.8941 | it_auc/class_0=0.8941 | it_loss=0.0351 | loss=0.0238 | same_auc/_mean=0.9719 | same_auc/class_0=0.9719 | same_loss=0.0168 | tr_auc/_mean=0.9840 | tr_auc/class_0=0.9840 | tr_loss=0.0075
# 10/300 * Epoch 10 (valid_es): auc/_mean=0.9195 | auc/class_0=0.9195 | loss=0.0307
# 10/300 * Epoch 10 (valid_it): auc/_mean=0.8941 | auc/class_0=0.8941 | loss=0.0351
# 10/300 * Epoch 10 (valid_tr): auc/_mean=0.9840 | auc/class_0=0.9840 | loss=0.0075
# 10/300 * Epoch 10 (valid_same): auc/_mean=0.9719 | auc/class_0=0.9719 | loss=0.0168
# 11/300 * Epoch (train):  30% 1280/4209 [06:32<14:57,  3.26it/s, loss=0.011]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 11/300 * Epoch (train): 100% 4209/4209 [21:31<00:00,  3.26it/s, loss=0.013]
# 11/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.023]
# 11/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.007]
# 11/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.004]
# 11/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.008]
# 11/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.20it/s, loss=0.021]
# [2020-05-08 04:31:37,507]
# 11/300 * Epoch 11 (_base): lr=2.500e-07 | momentum=0.9000
# 11/300 * Epoch 11 (train): auc/_mean=0.9747 | auc/class_0=0.9747 | loss=0.0151
# 11/300 * Epoch 11 (valid): auc/_mean=0.9334 | auc/class_0=0.9334 | es_auc/_mean=0.9200 | es_auc/class_0=0.9200 | es_loss=0.0294 | it_auc/_mean=0.8942 | it_auc/class_0=0.8942 | it_loss=0.0338 | loss=0.0230 | same_auc/_mean=0.9719 | same_auc/class_0=0.9719 | same_loss=0.0170 | tr_auc/_mean=0.9844 | tr_auc/class_0=0.9844 | tr_loss=0.0075
# 11/300 * Epoch 11 (valid_es): auc/_mean=0.9200 | auc/class_0=0.9200 | loss=0.0294
# 11/300 * Epoch 11 (valid_it): auc/_mean=0.8942 | auc/class_0=0.8942 | loss=0.0338
# 11/300 * Epoch 11 (valid_tr): auc/_mean=0.9844 | auc/class_0=0.9844 | loss=0.0075
# 11/300 * Epoch 11 (valid_same): auc/_mean=0.9719 | auc/class_0=0.9719 | loss=0.0170
# 12/300 * Epoch (train):  54% 2265/4209 [11:35<09:58,  3.25it/s, loss=0.008]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 12/300 * Epoch (train): 100% 4209/4209 [21:31<00:00,  3.26it/s, loss=0.014]
# 12/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.12it/s, loss=0.023]
# 12/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.91it/s, loss=0.004]
# 12/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.91it/s, loss=0.004]
# 12/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.86it/s, loss=0.008]
# 12/300 * Epoch (valid_same): 100% 468/468 [01:04<00:00,  7.26it/s, loss=0.021]
# [2020-05-08 04:55:20,724]
# 12/300 * Epoch 12 (_base): lr=2.500e-07 | momentum=0.9000
# 12/300 * Epoch 12 (train): auc/_mean=0.9750 | auc/class_0=0.9750 | loss=0.0149
# 12/300 * Epoch 12 (valid): auc/_mean=0.9330 | auc/class_0=0.9330 | es_auc/_mean=0.9198 | es_auc/class_0=0.9198 | es_loss=0.0298 | it_auc/_mean=0.8942 | it_auc/class_0=0.8942 | it_loss=0.0342 | loss=0.0233 | same_auc/_mean=0.9722 | same_auc/class_0=0.9722 | same_loss=0.0167 | tr_auc/_mean=0.9838 | tr_auc/class_0=0.9838 | tr_loss=0.0076
# 12/300 * Epoch 12 (valid_es): auc/_mean=0.9198 | auc/class_0=0.9198 | loss=0.0298
# 12/300 * Epoch 12 (valid_it): auc/_mean=0.8942 | auc/class_0=0.8942 | loss=0.0342
# 12/300 * Epoch 12 (valid_tr): auc/_mean=0.9838 | auc/class_0=0.9838 | loss=0.0076
# 12/300 * Epoch 12 (valid_same): auc/_mean=0.9722 | auc/class_0=0.9722 | loss=0.0167
# 13/300 * Epoch (train):  63% 2666/4209 [13:37<07:53,  3.26it/s, loss=0.016]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 131072.0
# 13/300 * Epoch (train):  74% 3110/4209 [15:53<05:37,  3.26it/s, loss=0.019]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 13/300 * Epoch (train):  86% 3632/4209 [18:34<02:57,  3.26it/s, loss=0.009]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 13/300 * Epoch (train): 100% 4209/4209 [21:31<00:00,  3.26it/s, loss=0.010]
# 13/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.022]
# 13/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.85it/s, loss=0.004]
# 13/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.005]
# 13/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.008]
# 13/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.19it/s, loss=0.021]
# [2020-05-08 05:19:04,842]
# 13/300 * Epoch 13 (_base): lr=6.250e-08 | momentum=0.9000
# 13/300 * Epoch 13 (train): auc/_mean=0.9755 | auc/class_0=0.9755 | loss=0.0148
# 13/300 * Epoch 13 (valid): auc/_mean=0.9323 | auc/class_0=0.9323 | es_auc/_mean=0.9190 | es_auc/class_0=0.9190 | es_loss=0.0290 | it_auc/_mean=0.8936 | it_auc/class_0=0.8936 | it_loss=0.0331 | loss=0.0227 | same_auc/_mean=0.9727 | same_auc/class_0=0.9727 | same_loss=0.0167 | tr_auc/_mean=0.9834 | tr_auc/class_0=0.9834 | tr_loss=0.0078
# 13/300 * Epoch 13 (valid_es): auc/_mean=0.9190 | auc/class_0=0.9190 | loss=0.0290
# 13/300 * Epoch 13 (valid_it): auc/_mean=0.8936 | auc/class_0=0.8936 | loss=0.0331
# 13/300 * Epoch 13 (valid_tr): auc/_mean=0.9834 | auc/class_0=0.9834 | loss=0.0078
# 13/300 * Epoch 13 (valid_same): auc/_mean=0.9727 | auc/class_0=0.9727 | loss=0.0167
# 14/300 * Epoch (train):  65% 2752/4209 [14:03<07:25,  3.27it/s, loss=0.010]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 14/300 * Epoch (train): 100% 4209/4209 [21:31<00:00,  3.26it/s, loss=0.011]
# 14/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.023]
# 14/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.85it/s, loss=0.006]
# 14/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.81it/s, loss=0.004]
# 14/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.80it/s, loss=0.008]
# 14/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.20it/s, loss=0.021]
# [2020-05-08 05:42:49,277]
# 14/300 * Epoch 14 (_base): lr=6.250e-08 | momentum=0.9000
# 14/300 * Epoch 14 (train): auc/_mean=0.9760 | auc/class_0=0.9760 | loss=0.0146
# 14/300 * Epoch 14 (valid): auc/_mean=0.9332 | auc/class_0=0.9332 | es_auc/_mean=0.9192 | es_auc/class_0=0.9192 | es_loss=0.0296 | it_auc/_mean=0.8950 | it_auc/class_0=0.8950 | it_loss=0.0334 | loss=0.0230 | same_auc/_mean=0.9729 | same_auc/class_0=0.9729 | same_loss=0.0165 | tr_auc/_mean=0.9837 | tr_auc/class_0=0.9837 | tr_loss=0.0076
# 14/300 * Epoch 14 (valid_es): auc/_mean=0.9192 | auc/class_0=0.9192 | loss=0.0296
# 14/300 * Epoch 14 (valid_it): auc/_mean=0.8950 | auc/class_0=0.8950 | loss=0.0334
# 14/300 * Epoch 14 (valid_tr): auc/_mean=0.9837 | auc/class_0=0.9837 | loss=0.0076
# 14/300 * Epoch 14 (valid_same): auc/_mean=0.9729 | auc/class_0=0.9729 | loss=0.0165
# 15/300 * Epoch (train):  32% 1339/4209 [06:50<14:39,  3.26it/s, loss=0.015]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 15/300 * Epoch (train):  86% 3626/4209 [18:31<02:58,  3.26it/s, loss=0.007]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 15/300 * Epoch (train): 100% 4209/4209 [21:30<00:00,  3.26it/s, loss=0.008]
# 15/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.07it/s, loss=0.023]
# 15/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.87it/s, loss=0.005]
# 15/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.004]
# 15/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.82it/s, loss=0.008]
# 15/300 * Epoch (valid_same): 100% 468/468 [01:04<00:00,  7.22it/s, loss=0.021]
# [2020-05-08 06:06:32,008]
# 15/300 * Epoch 15 (_base): lr=6.250e-08 | momentum=0.9000
# 15/300 * Epoch 15 (train): auc/_mean=0.9762 | auc/class_0=0.9762 | loss=0.0146
# 15/300 * Epoch 15 (valid): auc/_mean=0.9328 | auc/class_0=0.9328 | es_auc/_mean=0.9191 | es_auc/class_0=0.9191 | es_loss=0.0299 | it_auc/_mean=0.8943 | it_auc/class_0=0.8943 | it_loss=0.0338 | loss=0.0232 | same_auc/_mean=0.9729 | same_auc/class_0=0.9729 | same_loss=0.0164 | tr_auc/_mean=0.9834 | tr_auc/class_0=0.9834 | tr_loss=0.0077
# 15/300 * Epoch 15 (valid_es): auc/_mean=0.9191 | auc/class_0=0.9191 | loss=0.0299
# 15/300 * Epoch 15 (valid_it): auc/_mean=0.8943 | auc/class_0=0.8943 | loss=0.0338
# 15/300 * Epoch 15 (valid_tr): auc/_mean=0.9834 | auc/class_0=0.9834 | loss=0.0077
# 15/300 * Epoch 15 (valid_same): auc/_mean=0.9729 | auc/class_0=0.9729 | loss=0.0164
# 16/300 * Epoch (train): 100% 4209/4209 [21:31<00:00,  3.26it/s, loss=0.008]
# 16/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.024]
# 16/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.84it/s, loss=0.006]
# 16/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.004]
# 16/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.78it/s, loss=0.008]
# 16/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.19it/s, loss=0.021]
# [2020-05-08 06:30:15,787]
# 16/300 * Epoch 16 (_base): lr=6.250e-08 | momentum=0.9000
# 16/300 * Epoch 16 (train): auc/_mean=0.9764 | auc/class_0=0.9764 | loss=0.0145
# 16/300 * Epoch 16 (valid): auc/_mean=0.9329 | auc/class_0=0.9329 | es_auc/_mean=0.9193 | es_auc/class_0=0.9193 | es_loss=0.0305 | it_auc/_mean=0.8942 | it_auc/class_0=0.8942 | it_loss=0.0344 | loss=0.0236 | same_auc/_mean=0.9730 | same_auc/class_0=0.9730 | same_loss=0.0164 | tr_auc/_mean=0.9834 | tr_auc/class_0=0.9834 | tr_loss=0.0077
# 16/300 * Epoch 16 (valid_es): auc/_mean=0.9193 | auc/class_0=0.9193 | loss=0.0305
# 16/300 * Epoch 16 (valid_it): auc/_mean=0.8942 | auc/class_0=0.8942 | loss=0.0344
# 16/300 * Epoch 16 (valid_tr): auc/_mean=0.9834 | auc/class_0=0.9834 | loss=0.0077
# 16/300 * Epoch 16 (valid_same): auc/_mean=0.9730 | auc/class_0=0.9730 | loss=0.0164
# 17/300 * Epoch (train):  15% 620/4209 [03:10<18:23,  3.25it/s, loss=0.020]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 17/300 * Epoch (train):  81% 3417/4209 [17:31<04:03,  3.25it/s, loss=0.013]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 17/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.007]
# 17/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.023]
# 17/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.006]
# 17/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 17/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.76it/s, loss=0.008]
# 17/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.17it/s, loss=0.021]
# [2020-05-08 06:54:07,224]
# 17/300 * Epoch 17 (_base): lr=6.250e-08 | momentum=0.9000
# 17/300 * Epoch 17 (train): auc/_mean=0.9764 | auc/class_0=0.9764 | loss=0.0145
# 17/300 * Epoch 17 (valid): auc/_mean=0.9328 | auc/class_0=0.9328 | es_auc/_mean=0.9192 | es_auc/class_0=0.9192 | es_loss=0.0302 | it_auc/_mean=0.8940 | it_auc/class_0=0.8940 | it_loss=0.0341 | loss=0.0234 | same_auc/_mean=0.9729 | same_auc/class_0=0.9729 | same_loss=0.0164 | tr_auc/_mean=0.9832 | tr_auc/class_0=0.9832 | tr_loss=0.0077
# 17/300 * Epoch 17 (valid_es): auc/_mean=0.9192 | auc/class_0=0.9192 | loss=0.0302
# 17/300 * Epoch 17 (valid_it): auc/_mean=0.8940 | auc/class_0=0.8940 | loss=0.0341
# 17/300 * Epoch 17 (valid_tr): auc/_mean=0.9832 | auc/class_0=0.9832 | loss=0.0077
# 17/300 * Epoch 17 (valid_same): auc/_mean=0.9729 | auc/class_0=0.9729 | loss=0.0164
# 18/300 * Epoch (train):  50% 2100/4209 [10:46<10:50,  3.24it/s, loss=0.011]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 18/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.006]
# 18/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.00it/s, loss=0.023]
# 18/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.82it/s, loss=0.005]
# 18/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 18/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.73it/s, loss=0.008]
# 18/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.021]
# [2020-05-08 07:17:55,538]
# 18/300 * Epoch 18 (_base): lr=6.250e-08 | momentum=0.9000
# 18/300 * Epoch 18 (train): auc/_mean=0.9765 | auc/class_0=0.9765 | loss=0.0144
# 18/300 * Epoch 18 (valid): auc/_mean=0.9329 | auc/class_0=0.9329 | es_auc/_mean=0.9193 | es_auc/class_0=0.9193 | es_loss=0.0301 | it_auc/_mean=0.8944 | it_auc/class_0=0.8944 | it_loss=0.0340 | loss=0.0233 | same_auc/_mean=0.9730 | same_auc/class_0=0.9730 | same_loss=0.0164 | tr_auc/_mean=0.9834 | tr_auc/class_0=0.9834 | tr_loss=0.0077
# 18/300 * Epoch 18 (valid_es): auc/_mean=0.9193 | auc/class_0=0.9193 | loss=0.0301
# 18/300 * Epoch 18 (valid_it): auc/_mean=0.8944 | auc/class_0=0.8944 | loss=0.0340
# 18/300 * Epoch 18 (valid_tr): auc/_mean=0.9834 | auc/class_0=0.9834 | loss=0.0077
# 18/300 * Epoch 18 (valid_same): auc/_mean=0.9730 | auc/class_0=0.9730 | loss=0.0164
# 19/300 * Epoch (train):   0% 7/4209 [00:02<24:49,  2.82it/s, loss=0.018]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 19/300 * Epoch (train):  16% 694/4209 [03:33<18:00,  3.25it/s, loss=0.015]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 19/300 * Epoch (train): 100% 4209/4209 [21:35<00:00,  3.25it/s, loss=0.010]
# 19/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.04it/s, loss=0.023]
# 19/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.85it/s, loss=0.005]
# 19/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 19/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.77it/s, loss=0.008]
# 19/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.021]
# [2020-05-08 07:41:43,866]
# 19/300 * Epoch 19 (_base): lr=1.562e-08 | momentum=0.9000
# 19/300 * Epoch 19 (train): auc/_mean=0.9767 | auc/class_0=0.9767 | loss=0.0144
# 19/300 * Epoch 19 (valid): auc/_mean=0.9330 | auc/class_0=0.9330 | es_auc/_mean=0.9192 | es_auc/class_0=0.9192 | es_loss=0.0299 | it_auc/_mean=0.8945 | it_auc/class_0=0.8945 | it_loss=0.0337 | loss=0.0232 | same_auc/_mean=0.9731 | same_auc/class_0=0.9731 | same_loss=0.0164 | tr_auc/_mean=0.9834 | tr_auc/class_0=0.9834 | tr_loss=0.0077
# 19/300 * Epoch 19 (valid_es): auc/_mean=0.9192 | auc/class_0=0.9192 | loss=0.0299
# 19/300 * Epoch 19 (valid_it): auc/_mean=0.8945 | auc/class_0=0.8945 | loss=0.0337
# 19/300 * Epoch 19 (valid_tr): auc/_mean=0.9834 | auc/class_0=0.9834 | loss=0.0077
# 19/300 * Epoch 19 (valid_same): auc/_mean=0.9731 | auc/class_0=0.9731 | loss=0.0164
# 20/300 * Epoch (train):   9% 364/4209 [01:52<19:41,  3.26it/s, loss=0.019]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 20/300 * Epoch (train):  76% 3204/4209 [16:26<05:09,  3.24it/s, loss=0.014]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 32768.0
# 20/300 * Epoch (train): 100% 4209/4209 [21:36<00:00,  3.25it/s, loss=0.007]
# 20/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.04it/s, loss=0.023]
# 20/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.83it/s, loss=0.005]
# 20/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.80it/s, loss=0.004]
# 20/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.75it/s, loss=0.008]
# 20/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.021]
# [2020-05-08 08:05:34,749]
# 20/300 * Epoch 20 (_base): lr=1.562e-08 | momentum=0.9000
# 20/300 * Epoch 20 (train): auc/_mean=0.9766 | auc/class_0=0.9766 | loss=0.0144
# 20/300 * Epoch 20 (valid): auc/_mean=0.9331 | auc/class_0=0.9331 | es_auc/_mean=0.9193 | es_auc/class_0=0.9193 | es_loss=0.0304 | it_auc/_mean=0.8945 | it_auc/class_0=0.8945 | it_loss=0.0342 | loss=0.0235 | same_auc/_mean=0.9732 | same_auc/class_0=0.9732 | same_loss=0.0163 | tr_auc/_mean=0.9832 | tr_auc/class_0=0.9832 | tr_loss=0.0077
# 20/300 * Epoch 20 (valid_es): auc/_mean=0.9193 | auc/class_0=0.9193 | loss=0.0304
# 20/300 * Epoch 20 (valid_it): auc/_mean=0.8945 | auc/class_0=0.8945 | loss=0.0342
# 20/300 * Epoch 20 (valid_tr): auc/_mean=0.9832 | auc/class_0=0.9832 | loss=0.0077
# 20/300 * Epoch 20 (valid_same): auc/_mean=0.9732 | auc/class_0=0.9732 | loss=0.0163
# 21/300 * Epoch (train):  72% 3025/4209 [15:30<06:03,  3.25it/s, loss=0.008]Gradient overflow.  Skipping step, loss scaler 0 reducing loss scale to 65536.0
# 21/300 * Epoch (train): 100% 4209/4209 [21:34<00:00,  3.25it/s, loss=0.012]
# 21/300 * Epoch (valid): 100% 125/125 [00:17<00:00,  7.05it/s, loss=0.023]
# 21/300 * Epoch (valid_es): 100% 40/40 [00:05<00:00,  6.86it/s, loss=0.006]
# 21/300 * Epoch (valid_it): 100% 40/40 [00:05<00:00,  6.79it/s, loss=0.004]
# 21/300 * Epoch (valid_tr): 100% 47/47 [00:06<00:00,  6.75it/s, loss=0.008]
# 21/300 * Epoch (valid_same): 100% 468/468 [01:05<00:00,  7.18it/s, loss=0.021]
# [2020-05-08 08:29:22,394]
# 21/300 * Epoch 21 (_base): lr=1.562e-08 | momentum=0.9000
# 21/300 * Epoch 21 (train): auc/_mean=0.9767 | auc/class_0=0.9767 | loss=0.0144
# 21/300 * Epoch 21 (valid): auc/_mean=0.9332 | auc/class_0=0.9332 | es_auc/_mean=0.9196 | es_auc/class_0=0.9196 | es_loss=0.0305 | it_auc/_mean=0.8946 | it_auc/class_0=0.8946 | it_loss=0.0343 | loss=0.0235 | same_auc/_mean=0.9732 | same_auc/class_0=0.9732 | same_loss=0.0163 | tr_auc/_mean=0.9831 | tr_auc/class_0=0.9831 | tr_loss=0.0077
# 21/300 * Epoch 21 (valid_es): auc/_mean=0.9196 | auc/class_0=0.9196 | loss=0.0305
# 21/300 * Epoch 21 (valid_it): auc/_mean=0.8946 | auc/class_0=0.8946 | loss=0.0343
# 21/300 * Epoch 21 (valid_tr): auc/_mean=0.9831 | auc/class_0=0.9831 | loss=0.0077
# 21/300 * Epoch 21 (valid_same): auc/_mean=0.9732 | auc/class_0=0.9732 | loss=0.0163
# 22/300 * Epoch (train):  44% 1834/4209 [09:24<12:19,  3.21it/s, loss=0.016]

# %%
# for name, params in model.named_parameters():
#     print(name)

# %% [markdown]
# ####

# %%
# for i, row in df_train.iterrows():
#     print(list(row.keys().values))
#     break

# %%
--

# %%
CHECKPOINT = '/media/ssd/logs/jigsaw/js_v935_xlmrbtlg_10fr_pseudo/05_04_2020__14_16_58_lr1e-06_pseudo_train/simple/checkpoints/best.pth'

# %%
model = QuestModel(2)

checkpoint = torch.load(CHECKPOINT)#, map_location=device)   

model.load_state_dict(checkpoint['model_state_dict'])
del checkpoint

# %%
model = model.to(device)
_ = model.eval()

# %%
df_test = pd.read_csv('/kaggle/input/jigsaw-multilingual-toxic-comment-classification/test.csv')\
    .rename(columns={'content':'comment_text'})
ds = QuestDataset(df_test, train_mode=False, labeled=False)
loader = DataLoader(
        ds,
        num_workers=8,
        batch_size=batch_size,
    )

# %%
df_test.head()

# %%
y_pred = torch.zeros( len(ds), 2).to(device)

j = 0
with torch.no_grad():
    for data in tqdm(loader):
        x = data['features'].to(device)
        thish_batch_size = len(x)            
        
        
        y_pred[j:j+thish_batch_size] = model(x)
            
        j += thish_batch_size

# %%
from torch import sigmoid
y_pred_sigmoid = sigmoid(y_pred)

# %%
y_pred_sigmoid_one_np = y_pred_sigmoid.cpu().numpy()

# %%
df_sub['toxic'] = y_pred_sigmoid_one_np[:,1]

# %%
df_sub.to_csv('submission.csv', index=False)

# %%
df_sub
